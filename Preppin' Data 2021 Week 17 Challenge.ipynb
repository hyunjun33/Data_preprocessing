# %% [markdown]
# ## Week 17: Timesheet checks
#
# This challenge came about from a challenge Pat received as his friends and family have begun to learn about his super data preparation skills. Pat has built out a detailed set of requirements so this might be an easier challenge for some.
#
# The Challenge
#
# My employees log their hours daily and are contracted to 8 hours per week so I want to check their average number of hours worked over the last 2 weeks. Also, I allow for 20% of their time (not including Chats) to work on their own special projects, meaning they should be spending at least 80% of their time on Client items of work, so I also want to check that they are sticking to instructions by calculating the % of total hours spent on Client work. The task has three sets of requirements as the stakeholder is quite specific.
#
# ### Input
# One file but three people's data:
#
# ![img](https://1.bp.blogspot.com/-1QmUxFAp41Q/YIZ7-eVaQhI/AAAAAAAACJo/lhHLdDOU2nM_os8CkIgRqYYR2XPtvULZACLcBGAsYHQ/w640-h112/Screenshot%2B2021-04-26%2Bat%2B09.37.29.png)
#
# ### Requirment
# - Remove the ‘Totals’ Rows
# - Pivot Dates to rows and rename fields 'Date' and 'Hours'
# - Split the ‘Name, Age, Area of Work’ field into 3 Fields and Rename
# - Remove unnecessary fields
# - Remove the row where Dan was on Annual Leave and check the data type of the Hours Field.
# - Total up the number of hours spent on each area of work for each date by each employee.
#
# - First we are going to work out the avg number of hours per day worked by each employee
# - Calculate the total number of hours worked and days worked per person
# - Calculate the avg hours and remove unnecessary fields.
#
# - Now we are going to work out what % of their day (not including Chats) was spend on Client work.
# - Filter out Work related to Chats.
# - Calculate total number of hours spent working on each area for each employee
# - Calculate total number of hours spent working on both areas together for each employee
# - Join these totals together
# - Calculate the % of total and remove unnecessary fields
# - Filter the data to just show Client work
# - Join to the table with Avg hours to create your final output
#
# ### Output
# ![img](https://lh4.googleusercontent.com/Vt38vFKMGTPe8GuzPjuxQSPkM6ccj3n3U3ASMgiYbAGPejkADismHasgHjRxm5xttLTHolhy1HFO6pKylD98H8_hgeU-xt2n8yGc-UPd5oYDcvEpQrGjgm-4pbpJjFp7vcKpqzQ)
#
# One file:
#
# 4 fields:
# - Name
# - Area of Work
# - % of Total
# - Avg Number of Hours worked per day|
#
# 3 rows (4 rows including headers)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("./data/Preppin Data Challenge.xlsx")
df
# Out:
#          Name, Age, Area of Work                   Project  \
# 0                Dan, 28: Client           Client Meetings
# 1                Dan, 28: Client             Client Issues
# 2                Dan, 28: Client           Monthly Reports
# 3                Dan, 28: Client             Client Emails
# 4                Dan, 28: Client     Client Communications
# 5      Dan, 28: Special Projects             Virtual Space
# 6      Dan, 28: Special Projects     Presentation for Exec
# 7      Dan, 28: Special Projects                   Webinar
# 8      Dan, 28: Special Projects  Grad Scheme Organisation
# 9      Dan, 28: Special Projects               Team Social
# 10     Dan, 28: Special Projects         Social Committee
# 11     Dan, 28: Special Projects                 Mentoring
# 12                Dan, 28: Chats             Team Meetings
# 13                Dan, 28: Chats                   Minutes
# 14                Dan, 28: Chats          Coffee Catch Ups
# 15                Dan, 28: Chats      Personal development
# 16                Dan, 28: Chats          Company Meetings
# 17                           NaN     Overall Total for Dan
# 18            George, 34: Client           Client Meetings
# 19            George, 34: Client             Client Issues
# 20            George, 34: Client           Monthly Reports
# 21            George, 34: Client             Client Emails
# 22            George, 34: Client     Client Communications
# 23  George, 34: Special Projects             Virtual Space
# 24  George, 34: Special Projects     Presentation for Exec
# 25  George, 34: Special Projects                   Webinar
# 26  George, 34: Special Projects  Grad Scheme Organisation
# 27  George, 34: Special Projects               Team Social
# 28  George, 34: Special Projects         Social Committee
# 29  George, 34: Special Projects                 Mentoring
# 30             George, 34: Chats             Team Meetings
# 31             George, 34: Chats                   Minutes
# 32             George, 34: Chats          Coffee Catch Ups
# 33             George, 34: Chats      Personal development
# 34             George, 34: Chats          Company Meetings
# 35                           NaN  Overall Total for George
# 36               Sam, 45: Client           Client Meetings
# 37               Sam, 45: Client             Client Issues
# 38               Sam, 45: Client           Monthly Reports
# 39               Sam, 45: Client             Client Emails
# 40               Sam, 45: Client     Client Communications
# 41               Sam, 45: Client             Virtual Space
# 42     Sam, 45: Special Projects     Presentation for Exec
# 43     Sam, 45: Special Projects                   Webinar
# 44     Sam, 45: Special Projects  Grad Scheme Organisation
# 45     Sam, 45: Special Projects               Team Social
# 46     Sam, 45: Special Projects         Social Committee
# 47     Sam, 45: Special Projects                 Mentoring
# 48                Sam, 45: Chats             Team Meetings
# 49                Sam, 45: Chats                   Minutes
# 50                Sam, 45: Chats          Coffee Catch Ups
# 51                Sam, 45: Chats      Personal development
# 52                Sam, 45: Chats          Company Meetings
# 53                           NaN     Overall Total for Sam
#
#     2021-02-01 00:00:00  2021-02-02 00:00:00  2021-02-03 00:00:00  \
# 0                   NaN                  2.0                  NaN
# 1                   1.0                  1.5                  4.5
# 2                   NaN                  NaN                  NaN
# 3                   2.0                  0.5                  0.5
# 4                   1.0                  1.0                  NaN
# 5                   NaN                  NaN                  NaN
# 6                   NaN                  NaN                  NaN
# 7                   NaN                  NaN                  NaN
# 8                   1.0                  1.0                  NaN
# 9                   NaN                  NaN                  NaN
# 10                  NaN                  NaN                  0.5
# 11                  NaN                  NaN                  NaN
# 12                  2.0                  0.5                  2.0
# 13                  NaN                  0.5                  NaN
# 14                  NaN                  0.5                  NaN
# 15                  NaN                  NaN                  NaN
# 16                  1.0                  NaN                  NaN
# 17                  8.0                  7.5                  7.5
# 18                  1.0                  1.0                  2.0
# 19                  1.0                  1.0                  4.0
# 20                  NaN                  3.0                  NaN
# 21                  2.0                  1.0                  1.0
# 22                  1.0                  NaN                  1.0
# 23                  NaN                  NaN                  NaN
# 24                  NaN                  1.0                  NaN
# 25                  2.0                  NaN                  1.0
# 26                  NaN                  NaN                  NaN
# 27                  NaN                  NaN                  NaN
# 28                  NaN                  NaN                  NaN
# 29                  NaN                  NaN                  NaN
# 30                  1.0                  1.0                  1.0
# 31                  NaN                  NaN                  NaN
# 32                  NaN                  NaN                  NaN
# 33                  NaN                  NaN                  NaN
# 34                  1.0                  NaN                  NaN
# 35                  9.0                  8.0                 10.0
# 36                  3.0                  NaN                  NaN
# 37                  2.0                  2.0                  2.0
# 38                  NaN                  1.0                  1.0
# 39                  1.5                  1.5                  1.5
# 40                  NaN                  NaN                  NaN
# 41                  NaN                  NaN                  NaN
# 42                  2.0                  NaN                  NaN
# 43                  NaN                  NaN                  NaN
# 44                  NaN                  NaN                  NaN
# 45                  NaN                  NaN                  1.0
# 46                  NaN                  NaN                  NaN
# 47                  NaN                  NaN                  NaN
# 48                  NaN                  1.0                  1.0
# 49                  NaN                  1.0                  1.0
# 50                  NaN                  NaN                  NaN
# 51                  NaN                  NaN                  NaN
# 52                  NaN                  NaN                  NaN
# 53                  8.5                  6.5                  7.5
#
#     2021-02-04 00:00:00  2021-02-05 00:00:00  2021-02-08 00:00:00  \
# 0                   1.0                  NaN                  1.5
# 1                   3.5                 1.00                  2.0
# 2                   NaN                 2.00                  1.0
# 3                   0.5                 1.00                  1.0
# 4                   NaN                  NaN                  0.5
# 5                   0.5                 1.00                  1.5
# 6                   NaN                  NaN                  NaN
# 7                   0.5                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# 9                   NaN                  NaN                  NaN
# 10                  NaN                 0.50                  NaN
# 11                  0.5                  NaN                  NaN
# 12                  1.0                 1.25                  1.5
# 13                  NaN                 0.50                  NaN
# 14                  0.5                 1.00                  NaN
# 15                  NaN                  NaN                  NaN
# 16                  NaN                  NaN                  NaN
# 17                  8.0                 8.25                  9.0
# 18                  NaN                 1.00                  1.5
# 19                  3.5                 4.00                  2.0
# 20                  NaN                  NaN                  1.0
# 21                  1.0                 1.00                  1.0
# 22                  NaN                  NaN                  NaN
# 23                  NaN                 1.00                  1.5
# 24                  NaN                  NaN                  NaN
# 25                  2.0                  NaN                  NaN
# 26                  NaN                  NaN                  NaN
# 27                  NaN                  NaN                  NaN
# 28                  NaN                  NaN                  NaN
# 29                  NaN                  NaN                  NaN
# 30                  1.0                  NaN                  1.0
# 31                  NaN                  NaN                  NaN
# 32                  1.0                 1.00                  NaN
# 33                  NaN                  NaN                  NaN
# 34                  NaN                  NaN                  1.0
# 35                  8.5                 8.00                  9.0
# 36                  NaN                 2.00                  3.0
# 37                  2.0                 2.00                  2.0
# 38                  1.0                  NaN                  NaN
# 39                  1.5                 1.50                  1.5
# 40                  NaN                 1.00                  NaN
# 41                  NaN                  NaN                  NaN
# 42                  NaN                  NaN                  2.0
# 43                  NaN                  NaN                  NaN
# 44                  NaN                  NaN                  NaN
# 45                  NaN                  NaN                  NaN
# 46                  NaN                 1.00                  NaN
# 47                  NaN                  NaN                  NaN
# 48                  1.0                  NaN                  NaN
# 49                  1.0                  NaN                  NaN
# 50                  1.0                 1.00                  NaN
# 51                  NaN                  NaN                  NaN
# 52                  NaN                  NaN                  NaN
# 53                  7.5                 8.50                  8.5
#
#     2021-02-09 00:00:00  2021-02-10 00:00:00  2021-02-11 00:00:00  \
# 0                   0.5                  NaN                  NaN
# 1                   1.0                  2.0                  3.0
# 2                   1.0                  2.0                  1.0
# 3                   1.0                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# 5                   0.5                  1.5                  NaN
# 6                   1.5                  NaN                  1.0
# 7                   0.5                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# 9                   NaN                  0.5                  NaN
# 10                  NaN                  NaN                  1.0
# 11                  NaN                  NaN                  NaN
# 12                  1.0                  0.5                  NaN
# 13                  NaN                  NaN                  0.5
# 14                  0.5                  NaN                  NaN
# 15                  NaN                  1.5                  1.0
# 16                  NaN                  1.0                  NaN
# 17                  7.5                  9.0                  7.5
# 18                  0.5                  1.0                  NaN
# 19                  1.0                  2.0                  3.0
# 20                  2.0                  2.0                  1.0
# 21                  1.0                  1.0                  1.0
# 22                  NaN                  NaN                  NaN
# 23                  0.5                  1.5                  NaN
# 24                  1.5                  NaN                  NaN
# 25                  NaN                  NaN                  NaN
# 26                  NaN                  NaN                  NaN
# 27                  NaN                  NaN                  NaN
# 28                  NaN                  NaN                  NaN
# 29                  NaN                  NaN                  NaN
# 30                  1.0                  1.0                  1.0
# 31                  NaN                  NaN                  NaN
# 32                  0.5                  NaN                  1.0
# 33                  NaN                  NaN                  NaN
# 34                  NaN                  NaN                  NaN
# 35                  8.0                  8.5                  7.0
# 36                  NaN                  NaN                  NaN
# 37                  2.0                  2.0                  2.0
# 38                  1.0                  1.0                  1.0
# 39                  1.5                  1.5                  1.5
# 40                  NaN                  NaN                  NaN
# 41                  NaN                  NaN                  NaN
# 42                  NaN                  NaN                  NaN
# 43                  NaN                  NaN                  NaN
# 44                  NaN                  NaN                  NaN
# 45                  NaN                  1.0                  NaN
# 46                  NaN                  NaN                  NaN
# 47                  NaN                  NaN                  NaN
# 48                  1.0                  1.0                  1.0
# 49                  1.0                  1.0                  1.0
# 50                  NaN                  NaN                  1.0
# 51                  NaN                  NaN                  NaN
# 52                  NaN                  NaN                  NaN
# 53                  6.5                  7.5                  7.5
#
#    2021-02-12 00:00:00
# 0         Annual Leave
# 1         Annual Leave
# 2         Annual Leave
# 3         Annual Leave
# 4         Annual Leave
# 5         Annual Leave
# 6         Annual Leave
# 7         Annual Leave
# 8         Annual Leave
# 9         Annual Leave
# 10        Annual Leave
# 11        Annual Leave
# 12        Annual Leave
# 13        Annual Leave
# 14        Annual Leave
# 15        Annual Leave
# 16        Annual Leave
# 17                   0
# 18                   2
# 19                   4
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                   1
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                   1
# 33                 NaN
# 34                 NaN
# 35                   8
# 36                   2
# 37                   2
# 38                 NaN
# 39                 1.5
# 40                   1
# 41                 NaN
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45                 NaN
# 46                   1
# 47                 NaN
# 48                 NaN
# 49                 NaN
# 50                   1
# 51                 NaN
# 52                 NaN
# 53                 8.5

# %%
### Remove the ‘Totals’ Rows

# %%
total_index = df.loc[df["Name, Age, Area of Work"].isna()].index
df = df.drop(total_index, axis=0)

# %%
### Pivot Dates to rows and rename fields 'Date' and 'Hours'

# %%
df = df.melt(id_vars=["Name, Age, Area of Work", "Project"],
             var_name="Date",
             value_name="Hour")
df
# Out:
#     Name, Age, Area of Work                Project       Date Hour
# 0           Dan, 28: Client        Client Meetings 2021-02-01  NaN
# 1           Dan, 28: Client          Client Issues 2021-02-01  1.0
# 2           Dan, 28: Client        Monthly Reports 2021-02-01  NaN
# 3           Dan, 28: Client          Client Emails 2021-02-01  2.0
# 4           Dan, 28: Client  Client Communications 2021-02-01  1.0
# ..                      ...                    ...        ...  ...
# 505          Sam, 45: Chats          Team Meetings 2021-02-12  NaN
# 506          Sam, 45: Chats                Minutes 2021-02-12  NaN
# 507          Sam, 45: Chats       Coffee Catch Ups 2021-02-12    1
# 508          Sam, 45: Chats   Personal development 2021-02-12  NaN
# 509          Sam, 45: Chats       Company Meetings 2021-02-12  NaN
#
# [510 rows x 4 columns]

# %%
### Split the ‘Name, Age, Area of Work’ field into 3 Fields and Rename
### Remove unnecessary fields

# %%
name_age_work = (df["Name, Age, Area of Work"]
                    .map(lambda x: x.replace(":", "")
                    .split(" "))
                    .apply(pd.Series)
                )
df["Name"] = name_age_work[0]
df["Age"] = name_age_work[1]
df["Area of Work"] = name_age_work[2]
df["Name"] = df["Name"].str.replace(",", "")
df = df.drop(["Name, Age, Area of Work"], axis=1)
df = df.loc[:, ["Name", "Age", "Date", "Area of Work", "Hour"]]
df
# Out:
#     Name Age       Date Area of Work Hour
# 0    Dan  28 2021-02-01       Client  NaN
# 1    Dan  28 2021-02-01       Client  1.0
# 2    Dan  28 2021-02-01       Client  NaN
# 3    Dan  28 2021-02-01       Client  2.0
# 4    Dan  28 2021-02-01       Client  1.0
# ..   ...  ..        ...          ...  ...
# 505  Sam  45 2021-02-12        Chats  NaN
# 506  Sam  45 2021-02-12        Chats  NaN
# 507  Sam  45 2021-02-12        Chats    1
# 508  Sam  45 2021-02-12        Chats  NaN
# 509  Sam  45 2021-02-12        Chats  NaN
#
# [510 rows x 5 columns]

# %%
### Remove the row where Dan was on Annual Leave and check the data type of the Hours Field.
dan_remove_index = df.loc[(df["Name"] == "Dan") & (df["Hour"] == "Annual Leave")].index
df = df.drop(dan_remove_index, axis=0)
df
# Out:
#     Name Age       Date Area of Work Hour
# 0    Dan  28 2021-02-01       Client  NaN
# 1    Dan  28 2021-02-01       Client  1.0
# 2    Dan  28 2021-02-01       Client  NaN
# 3    Dan  28 2021-02-01       Client  2.0
# 4    Dan  28 2021-02-01       Client  1.0
# ..   ...  ..        ...          ...  ...
# 505  Sam  45 2021-02-12        Chats  NaN
# 506  Sam  45 2021-02-12        Chats  NaN
# 507  Sam  45 2021-02-12        Chats    1
# 508  Sam  45 2021-02-12        Chats  NaN
# 509  Sam  45 2021-02-12        Chats  NaN
#
# [493 rows x 5 columns]

# %%
### Total up the number of hours spent on each area of work for each date by each employee.
grouped = df.groupby(["Name", "Area of Work", "Date"])["Hour"].sum()
grouped
# Out:
# Name  Area of Work  Date
# Dan   Chats         2021-02-01     3.0
#                     2021-02-02     1.5
#                     2021-02-03     2.0
#                     2021-02-04     1.5
#                     2021-02-05    2.75
#                                   ...
# Sam   Special       2021-02-08     2.0
#                     2021-02-09       0
#                     2021-02-10     1.0
#                     2021-02-11       0
#                     2021-02-12       1
# Name: Hour, Length: 87, dtype: object

# %%
### First we are going to work out the avg number of hours per day worked by each employee
avg_hours_per_day = df.groupby(["Name", "Date"])["Hour"].mean()
avg_hours_per_day
# Out:
# Name    Date
# Dan     2021-02-01    1.333333
#         2021-02-02    0.937500
#         2021-02-03    1.875000
#         2021-02-04    1.000000
#         2021-02-05    1.031250
#         2021-02-08    1.285714
#         2021-02-09    0.833333
#         2021-02-10    1.285714
#         2021-02-11    1.250000
# George  2021-02-01    1.285714
#         2021-02-02    1.333333
#         2021-02-03    1.666667
#         2021-02-04    1.700000
#         2021-02-05    1.600000
#         2021-02-08    1.285714
#         2021-02-09    1.000000
#         2021-02-10    1.416667
#         2021-02-11    1.400000
#         2021-02-12    2.000000
# Sam     2021-02-01    2.125000
#         2021-02-02    1.300000
#         2021-02-03    1.250000
#         2021-02-04    1.250000
#         2021-02-05    1.416667
#         2021-02-08    2.125000
#         2021-02-09    1.300000
#         2021-02-10    1.250000
#         2021-02-11    1.250000
#         2021-02-12    1.416667
# Name: Hour, dtype: float64

# %%
### Calculate the total number of hours worked and days worked per person
group_1 = df.groupby(["Name"])["Hour"].sum()
group_2 = df.groupby(["Name"])["Date"].nunique()
total = pd.concat([group_1, group_2], axis=1).rename(columns={"Hour": "Total Hours", "Date": "Total Days"})
total
# Out:
#        Total Hours  Total Days
# Name
# Dan          72.25           9
# George        84.0          10
# Sam           77.0          10

# %%
### Calculate the avg hours and remove unnecessary fields.
total["Avg Hours"] = total["Total Hours"] / total["Total Days"]
total
# Out:
#        Total Hours  Total Days Avg Hours
# Name
# Dan          72.25           9  8.027778
# George        84.0          10       8.4
# Sam           77.0          10       7.7

# %%
### Now we are going to work out what % of their day (not including Chats) was spend on Client work.

# %%
### Filter out Work related to Chats.
without_chat = df.loc[df["Area of Work"] != "Chats"]
without_chat
# Out:
#     Name Age       Date Area of Work Hour
# 0    Dan  28 2021-02-01       Client  NaN
# 1    Dan  28 2021-02-01       Client  1.0
# 2    Dan  28 2021-02-01       Client  NaN
# 3    Dan  28 2021-02-01       Client  2.0
# 4    Dan  28 2021-02-01       Client  1.0
# ..   ...  ..        ...          ...  ...
# 500  Sam  45 2021-02-12      Special  NaN
# 501  Sam  45 2021-02-12      Special  NaN
# 502  Sam  45 2021-02-12      Special  NaN
# 503  Sam  45 2021-02-12      Special    1
# 504  Sam  45 2021-02-12      Special  NaN
#
# [348 rows x 5 columns]

# %%
### Calculate total number of hours spent working on each area for each employee
group_1 = without_chat.groupby(["Name", "Area of Work"])["Hour"].sum().to_frame()
group_1 = group_1.reset_index()
group_1
# Out:
#      Name Area of Work  Hour
# 0     Dan       Client  40.5
# 1     Dan      Special  13.5
# 2  George       Client  56.5
# 3  George      Special  13.0
# 4     Sam       Client  53.0
# 5     Sam      Special   8.0

# %%
### Calculate total number of hours spent working on both areas together for each employee
group_2 = without_chat.groupby(["Name"])["Hour"].sum()
group_2
# Out:
# Name
# Dan       54.0
# George    69.5
# Sam       61.0
# Name: Hour, dtype: object

# %%
area_total = group_1.merge(group_2, how="left", on="Name").rename(columns={"Hour_x": "Area Hours", 
                                                                           "Hour_y": "Total Hours"})
# Out:
#      Name Area of Work Area Hours Total Hours
# 0     Dan       Client       40.5        54.0
# 1     Dan      Special       13.5        54.0
# 2  George       Client       56.5        69.5
# 3  George      Special       13.0        69.5
# 4     Sam       Client       53.0        61.0
# 5     Sam      Special        8.0        61.0
