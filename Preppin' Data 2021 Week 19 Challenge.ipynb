# %% [markdown]
# ## 2021: Week 19 Prep Air Project Details
#
# Continuing on our fundamental skills theme in May, this week's challenge is all about string calculations. If you want to know more about what String data is and how you might want to work with it, you might want to check out our how to... deal with strings post. Pay particular attention to split, right, mid and find if you're getting stuck with this challenge! I've written another guide to the common functions that you might find use when working with Strings in Tableau.
#
# ### The Challenge
# This week we are trying to find out more detail on what is going on with the project over runs in Prep Air (every data prepper's favourite airline). To get more detail than just what was shared last week we've uncovered the commentary log that sits behind our project management system. Like any system that holds the detail shown on the programme's interface in a log file, it has great detail but held in an unfriendly way.
#
# We need your help to get stuck into the messy data and extract out the useful details.
#
# ### Input
# One Excel file with 5 sheets of data.
#
# ![img](https://1.bp.blogspot.com/-_RJxcg2g448/YJUmTjDio2I/AAAAAAAACKg/yS9RP61aW5kT_ns68lqarxS17Bc15u03QCLcBGAsYHQ/w640-h126/Screenshot%2B2021-05-07%2Bat%2B12.36.27.png)
#
# There is one main page of data with four lookup tables that will help you change some abbreviations and codes to be full words.
#
# ### Requirement
# - Input the data
#
# There are lots of different ways you can do this challenge so rather than a step-by-step set of requirements, feel free to create each of these data fields in whatever order you like:
#
# - 'Week' with the word week and week number together 'Week x'
# - 'Project' with the full project name
# - 'Sub-Project' with the full sub-project name
# - 'Task' with the full type of task
# - 'Name' with the owner of the task's full name (Week 18's output can help you check these if needed)
# - 'Days Noted' some fields have comments that say how many days tasks might take. This field should note the number of days mentioned if said in the comment otherwise leave as a null.
# - 'Detail' the description from the system output with the project details in the [ ]
# - Output the file
#
# ### Output
#
# ![img](https://1.bp.blogspot.com/-0kJkW2UFz6c/YJVDcvzWB_I/AAAAAAAACKo/7bPo-kni-agXtQhj5a7noeGeri2oDCo_wCLcBGAsYHQ/w640-h136/Screenshot%2B2021-05-07%2Bat%2B14.40.44.png)
#
# One file
# - 7 data fields:
#     - Week
#     - Project
#     - Sub-Project
#     - Task
#     - Name
#     - Days Needed
#     - Detail
#
# 18 rows of data (19 including headers)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Input the data
data = pd.read_excel("./data/PD 2021 Week 19 Input.xlsx", 
                     sheet_name=["Project Schedule Updates", "Project Lookup Table", "Sub-Project Lookup Table",
                                 "Task Lookup Table", "Owner Lookup Table"])

# %%
project_schedule = data["Project Schedule Updates"].copy()
project_schedule
# Out:
#    Week                                         Commentary
# 0  16.0  [NLS/Op-Sc] Delivered scope for the project. R...
# 1  17.0  [NLS/Op-Bu] Build kickoff but long project. je...
# 2  18.0  [NLS/Op-De] Long delivery process has begun at...
# 3  19.0  [NTI/Mar-Bu] Project build commences. Will be ...
# 4  20.0  [NTI/Mar-De] Delivery next week around 8 days....

# %%
tmp = project_schedule["Commentary"].map(lambda x: x.split("[")).apply(pd.Series)
tmp = pd.concat([project_schedule["Week"], tmp], axis=1)
tmp = tmp.melt(id_vars="Week").dropna().loc[5:, ["Week", "value"]]

project_schedule = tmp.copy()
project_schedule = project_schedule.rename(columns={"value": "Commentary"})
project_schedule
# Out:
#     Week                                         Commentary
# 5   16.0  NLS/Op-Sc] Delivered scope for the project. Re...
# 6   17.0   NLS/Op-Bu] Build kickoff but long project. jen.
# 7   18.0  NLS/Op-De] Long delivery process has begun at ...
# 8   19.0  NTI/Mar-Bu] Project build commences. Will be c...
# 9   20.0  NTI/Mar-De] Delivery next week around 8 days. ...
# 11  17.0                 NLS/Mar-Sc] Scope completed. tom.
# 12  18.0  NLS/Mar-De] Similar to the operations team. 8 ...
# 13  19.0  NTI/Op-Bu] Longer build than the easy marketin...
# 14  20.0  NTI/Ops-De] Delivery also next week. Same as t...
# 16  17.0        NLS/Mar-Bu] Marketing Build complete. tom.
# 17  18.0  NTI/Op-Sc] New project scope delivered. Tough ...
# 18  19.0  SPS/Mar-De] Deliver delayed to next week as I'...
# 21  17.0  SPS/Mar-Sc] Completed but late in the week due...
# 22  18.0  NTI/Mar-Sc] Need to balance resourcing careful...
# 26  17.0  SPS/Op-Sc] Scope complete but weekend delivery...
# 27  18.0  SPS/Op-Bu] Complete and awaiting marketing del...
# 32  18.0  SPS/Mar-Bu] Build is longer than expected with...
# 37  18.0    SPS/Op-De] Delivery process started early. jon.

# %%
### Week' with the word week and week number together 'Week x'

# %%
project_schedule["Week"] = project_schedule["Week"].astype(int).astype(str)
project_schedule["Week"] = "Week " + project_schedule["Week"]
project_schedule
# Out:
#        Week                                         Commentary
# 5   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 6   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 7   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 8   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 9   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 11  Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 12  Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 13  Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 14  Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 16  Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 17  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 18  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 21  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 22  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 26  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 27  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 32  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 37  Week 18    SPS/Op-De] Delivery process started early. jon.

# %%
### 'Project' with the full project name

# %%
project_code = data["Project Lookup Table"].copy()

# %%
project_schedule["project_sub_task"] = project_schedule["Commentary"].map(lambda x: x.split(" ")[0])
project_schedule
# Out:
#        Week                                         Commentary  \
# 5   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 6   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 7   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 8   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 9   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 11  Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 12  Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 13  Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 14  Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 16  Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 17  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 18  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 21  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 22  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 26  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 27  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 32  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 37  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task
# 5        NLS/Op-Sc]
# 6        NLS/Op-Bu]
# 7        NLS/Op-De]
# 8       NTI/Mar-Bu]
# 9       NTI/Mar-De]
# 11      NLS/Mar-Sc]
# 12      NLS/Mar-De]
# 13       NTI/Op-Bu]
# 14      NTI/Ops-De]
# 16      NLS/Mar-Bu]
# 17       NTI/Op-Sc]
# 18      SPS/Mar-De]
# 21      SPS/Mar-Sc]
# 22      NTI/Mar-Sc]
# 26       SPS/Op-Sc]
# 27       SPS/Op-Bu]
# 32      SPS/Mar-Bu]
# 37       SPS/Op-De]

# %%
project_schedule["Project"] = project_schedule["project_sub_task"].map(lambda x: x.split("/")[0])

# %%
project_schedule = (project_schedule
                        .merge(project_code, how="left", left_on="Project", right_on="Project Code")
                        .drop(["Project_x"], axis=1)
                        .rename(columns={"Project_y" : "Project"}))
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme
# 2        NLS/Op-De]          NLS     New Loyalty Scheme
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory
# 4       NTI/Mar-De]          NTI  New Trolley Inventory
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory
# 8       NTI/Ops-De]          NTI  New Trolley Inventory
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory
# 11      SPS/Mar-De]          SPS            Spring Sale
# 12      SPS/Mar-Sc]          SPS            Spring Sale
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory
# 14       SPS/Op-Sc]          SPS            Spring Sale
# 15       SPS/Op-Bu]          SPS            Spring Sale
# 16      SPS/Mar-Bu]          SPS            Spring Sale
# 17       SPS/Op-De]          SPS            Spring Sale

# %%
### Sub-Project' with the full sub-project name

# %%
project_schedule["Sub-Project"] = project_schedule["project_sub_task"].map(lambda x: x.split("/")[1].split("-")[0])

# %%
project_schedule["Sub-Project"][8] = project_schedule["Sub-Project"][8].replace("s", "")
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project Sub-Project
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme          Op
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme          Op
# 2        NLS/Op-De]          NLS     New Loyalty Scheme          Op
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory         Mar
# 4       NTI/Mar-De]          NTI  New Trolley Inventory         Mar
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme         Mar
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme         Mar
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory          Op
# 8       NTI/Ops-De]          NTI  New Trolley Inventory          Op
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme         Mar
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory          Op
# 11      SPS/Mar-De]          SPS            Spring Sale         Mar
# 12      SPS/Mar-Sc]          SPS            Spring Sale         Mar
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory         Mar
# 14       SPS/Op-Sc]          SPS            Spring Sale          Op
# 15       SPS/Op-Bu]          SPS            Spring Sale          Op
# 16      SPS/Mar-Bu]          SPS            Spring Sale         Mar
# 17       SPS/Op-De]          SPS            Spring Sale          Op

# %%
sub_project_code = data["Sub-Project Lookup Table"].copy()
sub_project_code["Sub-Project Code"] = sub_project_code["Sub-Project Code"].str.capitalize()
sub_project_code
# Out:
#   Sub-Project Code Sub-Project
# 0              Mar   Marketing
# 1               Op  Operations

# %%
project_schedule = (project_schedule
                        .merge(sub_project_code, how="left", left_on="Sub-Project", right_on="Sub-Project Code")
                        .drop(["Sub-Project_x"], axis=1)
                        .rename(columns={"Sub-Project_y" : "Sub-Project"})
                   )
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project Sub-Project Code  \
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme               Op
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme               Op
# 2        NLS/Op-De]          NLS     New Loyalty Scheme               Op
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory              Mar
# 4       NTI/Mar-De]          NTI  New Trolley Inventory              Mar
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme              Mar
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme              Mar
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory               Op
# 8       NTI/Ops-De]          NTI  New Trolley Inventory               Op
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme              Mar
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory               Op
# 11      SPS/Mar-De]          SPS            Spring Sale              Mar
# 12      SPS/Mar-Sc]          SPS            Spring Sale              Mar
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory              Mar
# 14       SPS/Op-Sc]          SPS            Spring Sale               Op
# 15       SPS/Op-Bu]          SPS            Spring Sale               Op
# 16      SPS/Mar-Bu]          SPS            Spring Sale              Mar
# 17       SPS/Op-De]          SPS            Spring Sale               Op
#
#    Sub-Project
# 0   Operations
# 1   Operations
# 2   Operations
# 3    Marketing
# 4    Marketing
# 5    Marketing
# 6    Marketing
# 7   Operations
# 8   Operations
# 9    Marketing
# 10  Operations
# 11   Marketing
# 12   Marketing
# 13   Marketing
# 14  Operations
# 15  Operations
# 16   Marketing
# 17  Operations

# %%
### 'Task' with the full type of task

# %%
task_code = data["Task Lookup Table"].copy()
task_code
# Out:
#   Task Code     Task
# 0        Sc    Scope
# 1        Bu    Build
# 2        De  Deliver

# %%
project_schedule["Task"] = project_schedule["project_sub_task"].map(lambda x: x.split("-")[1].replace("]", ""))
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project Sub-Project Code  \
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme               Op
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme               Op
# 2        NLS/Op-De]          NLS     New Loyalty Scheme               Op
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory              Mar
# 4       NTI/Mar-De]          NTI  New Trolley Inventory              Mar
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme              Mar
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme              Mar
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory               Op
# 8       NTI/Ops-De]          NTI  New Trolley Inventory               Op
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme              Mar
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory               Op
# 11      SPS/Mar-De]          SPS            Spring Sale              Mar
# 12      SPS/Mar-Sc]          SPS            Spring Sale              Mar
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory              Mar
# 14       SPS/Op-Sc]          SPS            Spring Sale               Op
# 15       SPS/Op-Bu]          SPS            Spring Sale               Op
# 16      SPS/Mar-Bu]          SPS            Spring Sale              Mar
# 17       SPS/Op-De]          SPS            Spring Sale               Op
#
#    Sub-Project Task
# 0   Operations   Sc
# 1   Operations   Bu
# 2   Operations   De
# 3    Marketing   Bu
# 4    Marketing   De
# 5    Marketing   Sc
# 6    Marketing   De
# 7   Operations   Bu
# 8   Operations   De
# 9    Marketing   Bu
# 10  Operations   Sc
# 11   Marketing   De
# 12   Marketing   Sc
# 13   Marketing   Sc
# 14  Operations   Sc
# 15  Operations   Bu
# 16   Marketing   Bu
# 17  Operations   De

# %%
project_schedule = (project_schedule
                        .merge(task_code, how="left", left_on="Task", right_on="Task Code")
                        .drop(["Task_x"], axis=1)
                        .rename(columns={"Task_y" : "Task"})
                   )
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project Sub-Project Code  \
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme               Op
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme               Op
# 2        NLS/Op-De]          NLS     New Loyalty Scheme               Op
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory              Mar
# 4       NTI/Mar-De]          NTI  New Trolley Inventory              Mar
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme              Mar
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme              Mar
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory               Op
# 8       NTI/Ops-De]          NTI  New Trolley Inventory               Op
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme              Mar
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory               Op
# 11      SPS/Mar-De]          SPS            Spring Sale              Mar
# 12      SPS/Mar-Sc]          SPS            Spring Sale              Mar
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory              Mar
# 14       SPS/Op-Sc]          SPS            Spring Sale               Op
# 15       SPS/Op-Bu]          SPS            Spring Sale               Op
# 16      SPS/Mar-Bu]          SPS            Spring Sale              Mar
# 17       SPS/Op-De]          SPS            Spring Sale               Op
#
#    Sub-Project Task Code     Task
# 0   Operations        Sc    Scope
# 1   Operations        Bu    Build
# 2   Operations        De  Deliver
# 3    Marketing        Bu    Build
# 4    Marketing        De  Deliver
# 5    Marketing        Sc    Scope
# 6    Marketing        De  Deliver
# 7   Operations        Bu    Build
# 8   Operations        De  Deliver
# 9    Marketing        Bu    Build
# 10  Operations        Sc    Scope
# 11   Marketing        De  Deliver
# 12   Marketing        Sc    Scope
# 13   Marketing        Sc    Scope
# 14  Operations        Sc    Scope
# 15  Operations        Bu    Build
# 16   Marketing        Bu    Build
# 17  Operations        De  Deliver

# %%
### 'Name' with the owner of the task's full name (Week 18's output can help you check these if needed)

# %%
owner_code = data["Owner Lookup Table"].copy()
owner_code
# Out:
#   Abbreviation      Name
# 0          Tom       Tom
# 1          Jen     Jenny
# 2          Jon  Jonathan
# 3          Car      Carl

# %%
project_schedule["Name"] = project_schedule["Commentary"].map(lambda x: x.split(".")[-2].strip())
project_schedule["Name"] = project_schedule["Name"].map(lambda x: x.capitalize())
project_schedule["Name"]
# Out:
# 0     Jen
# 1     Jen
# 2     Jen
# 3     Tom
# 4     Tom
# 5     Tom
# 6     Tom
# 7     Jen
# 8     Jen
# 9     Tom
# 10    Jen
# 11    Car
# 12    Car
# 13    Tom
# 14    Jon
# 15    Jon
# 16    Car
# 17    Jon
# Name: Name, dtype: object

# %% [markdown]
# ### 'Days Noted' some fields have comments that say how many days tasks might take
# - This field should note the number of days mentioned if said in the comment otherwise leave as a null

# %%
project_schedule = (project_schedule
                        .merge(owner_code, how="left", left_on="Name", right_on="Abbreviation")
                        .drop(["Name_x"], axis=1)
                        .rename(columns={"Name_y": "Name"}))
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project Sub-Project Code  \
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme               Op
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme               Op
# 2        NLS/Op-De]          NLS     New Loyalty Scheme               Op
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory              Mar
# 4       NTI/Mar-De]          NTI  New Trolley Inventory              Mar
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme              Mar
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme              Mar
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory               Op
# 8       NTI/Ops-De]          NTI  New Trolley Inventory               Op
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme              Mar
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory               Op
# 11      SPS/Mar-De]          SPS            Spring Sale              Mar
# 12      SPS/Mar-Sc]          SPS            Spring Sale              Mar
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory              Mar
# 14       SPS/Op-Sc]          SPS            Spring Sale               Op
# 15       SPS/Op-Bu]          SPS            Spring Sale               Op
# 16      SPS/Mar-Bu]          SPS            Spring Sale              Mar
# 17       SPS/Op-De]          SPS            Spring Sale               Op
#
#    Sub-Project Task Code     Task Abbreviation      Name
# 0   Operations        Sc    Scope          Jen     Jenny
# 1   Operations        Bu    Build          Jen     Jenny
# 2   Operations        De  Deliver          Jen     Jenny
# 3    Marketing        Bu    Build          Tom       Tom
# 4    Marketing        De  Deliver          Tom       Tom
# 5    Marketing        Sc    Scope          Tom       Tom
# 6    Marketing        De  Deliver          Tom       Tom
# 7   Operations        Bu    Build          Jen     Jenny
# 8   Operations        De  Deliver          Jen     Jenny
# 9    Marketing        Bu    Build          Tom       Tom
# 10  Operations        Sc    Scope          Jen     Jenny
# 11   Marketing        De  Deliver          Car      Carl
# 12   Marketing        Sc    Scope          Car      Carl
# 13   Marketing        Sc    Scope          Tom       Tom
# 14  Operations        Sc    Scope          Jon  Jonathan
# 15  Operations        Bu    Build          Jon  Jonathan
# 16   Marketing        Bu    Build          Car      Carl
# 17  Operations        De  Deliver          Jon  Jonathan

# %%
import re
days = project_schedule["Commentary"].map(lambda x: re.findall('[0-9]+', x))
days = days.str[0]
days
# Out:
# 0     NaN
# 1     NaN
# 2      10
# 3       5
# 4       8
# 5     NaN
# 6       8
# 7       2
# 8       8
# 9     NaN
# 10      4
# 11    NaN
# 12      3
# 13    NaN
# 14    NaN
# 15    NaN
# 16      5
# 17    NaN
# Name: Commentary, dtype: object

# %%
project_schedule["Days Needed"] = days
project_schedule
# Out:
#        Week                                         Commentary  \
# 0   Week 16  NLS/Op-Sc] Delivered scope for the project. Re...
# 1   Week 17   NLS/Op-Bu] Build kickoff but long project. jen.
# 2   Week 18  NLS/Op-De] Long delivery process has begun at ...
# 3   Week 19  NTI/Mar-Bu] Project build commences. Will be c...
# 4   Week 20  NTI/Mar-De] Delivery next week around 8 days. ...
# 5   Week 17                 NLS/Mar-Sc] Scope completed. tom.
# 6   Week 18  NLS/Mar-De] Similar to the operations team. 8 ...
# 7   Week 19  NTI/Op-Bu] Longer build than the easy marketin...
# 8   Week 20  NTI/Ops-De] Delivery also next week. Same as t...
# 9   Week 17        NLS/Mar-Bu] Marketing Build complete. tom.
# 10  Week 18  NTI/Op-Sc] New project scope delivered. Tough ...
# 11  Week 19  SPS/Mar-De] Deliver delayed to next week as I'...
# 12  Week 17  SPS/Mar-Sc] Completed but late in the week due...
# 13  Week 18  NTI/Mar-Sc] Need to balance resourcing careful...
# 14  Week 17  SPS/Op-Sc] Scope complete but weekend delivery...
# 15  Week 18  SPS/Op-Bu] Complete and awaiting marketing del...
# 16  Week 18  SPS/Mar-Bu] Build is longer than expected with...
# 17  Week 18    SPS/Op-De] Delivery process started early. jon.
#
#    project_sub_task Project Code                Project Sub-Project Code  \
# 0        NLS/Op-Sc]          NLS     New Loyalty Scheme               Op
# 1        NLS/Op-Bu]          NLS     New Loyalty Scheme               Op
# 2        NLS/Op-De]          NLS     New Loyalty Scheme               Op
# 3       NTI/Mar-Bu]          NTI  New Trolley Inventory              Mar
# 4       NTI/Mar-De]          NTI  New Trolley Inventory              Mar
# 5       NLS/Mar-Sc]          NLS     New Loyalty Scheme              Mar
# 6       NLS/Mar-De]          NLS     New Loyalty Scheme              Mar
# 7        NTI/Op-Bu]          NTI  New Trolley Inventory               Op
# 8       NTI/Ops-De]          NTI  New Trolley Inventory               Op
# 9       NLS/Mar-Bu]          NLS     New Loyalty Scheme              Mar
# 10       NTI/Op-Sc]          NTI  New Trolley Inventory               Op
# 11      SPS/Mar-De]          SPS            Spring Sale              Mar
# 12      SPS/Mar-Sc]          SPS            Spring Sale              Mar
# 13      NTI/Mar-Sc]          NTI  New Trolley Inventory              Mar
# 14       SPS/Op-Sc]          SPS            Spring Sale               Op
# 15       SPS/Op-Bu]          SPS            Spring Sale               Op
# 16      SPS/Mar-Bu]          SPS            Spring Sale              Mar
# 17       SPS/Op-De]          SPS            Spring Sale               Op
#
#    Sub-Project Task Code     Task Abbreviation      Name Days Needed
# 0   Operations        Sc    Scope          Jen     Jenny         NaN
# 1   Operations        Bu    Build          Jen     Jenny         NaN
# 2   Operations        De  Deliver          Jen     Jenny          10
# 3    Marketing        Bu    Build          Tom       Tom           5
# 4    Marketing        De  Deliver          Tom       Tom           8
# 5    Marketing        Sc    Scope          Tom       Tom         NaN
# 6    Marketing        De  Deliver          Tom       Tom           8
# 7   Operations        Bu    Build          Jen     Jenny           2
# 8   Operations        De  Deliver          Jen     Jenny           8
# 9    Marketing        Bu    Build          Tom       Tom         NaN
# 10  Operations        Sc    Scope          Jen     Jenny           4
# 11   Marketing        De  Deliver          Car      Carl         NaN
# 12   Marketing        Sc    Scope          Car      Carl           3
# 13   Marketing        Sc    Scope          Tom       Tom         NaN
# 14  Operations        Sc    Scope          Jon  Jonathan         NaN
# 15  Operations        Bu    Build          Jon  Jonathan         NaN
# 16   Marketing        Bu    Build          Car      Carl           5
# 17  Operations        De  Deliver          Jon  Jonathan         NaN

# %% [markdown]
# ### 'Detail' the description from the system output with the project details in the [ ]

# %%
project_schedule["Detail"] = project_schedule["Commentary"].map(lambda x: x.split("]")[1])
project_schedule = project_schedule.drop(["Commentary", "project_sub_task", "Project Code", "Sub-Project Code",
                               "Task Code", "Abbreviation"], axis=1).sort_values(by=["Project", "Sub-Project"])
project_schedule
# Out:
#        Week                Project Sub-Project     Task      Name Days Needed  \
# 5   Week 17     New Loyalty Scheme   Marketing    Scope       Tom         NaN
# 6   Week 18     New Loyalty Scheme   Marketing  Deliver       Tom           8
# 9   Week 17     New Loyalty Scheme   Marketing    Build       Tom         NaN
# 0   Week 16     New Loyalty Scheme  Operations    Scope     Jenny         NaN
# 1   Week 17     New Loyalty Scheme  Operations    Build     Jenny         NaN
# 2   Week 18     New Loyalty Scheme  Operations  Deliver     Jenny          10
# 3   Week 19  New Trolley Inventory   Marketing    Build       Tom           5
# 4   Week 20  New Trolley Inventory   Marketing  Deliver       Tom           8
# 13  Week 18  New Trolley Inventory   Marketing    Scope       Tom         NaN
# 7   Week 19  New Trolley Inventory  Operations    Build     Jenny           2
# 8   Week 20  New Trolley Inventory  Operations  Deliver     Jenny           8
# 10  Week 18  New Trolley Inventory  Operations    Scope     Jenny           4
# 11  Week 19            Spring Sale   Marketing  Deliver      Carl         NaN
# 12  Week 17            Spring Sale   Marketing    Scope      Carl           3
# 16  Week 18            Spring Sale   Marketing    Build      Carl           5
# 14  Week 17            Spring Sale  Operations    Scope  Jonathan         NaN
# 15  Week 18            Spring Sale  Operations    Build  Jonathan         NaN
# 17  Week 18            Spring Sale  Operations  Deliver  Jonathan         NaN
#
#                                                Detail
# 5                              Scope completed. tom.
# 6    Similar to the operations team. 8 days effort...
# 9                     Marketing Build complete. tom.
# 0    Delivered scope for the project. Resourcing f...
# 1               Build kickoff but long project. jen.
# 2    Long delivery process has begun at least 10 d...
# 3    Project build commences. Will be completed in...
# 4             Delivery next week around 8 days. tom.
# 13   Need to balance resourcing carefully with two...
# 7    Longer build than the easy marketing project ...
# 8    Delivery also next week. Same as tom, I need ...
# 10   New project scope delivered. Tough to juggle ...
# 11   Deliver delayed to next week as I'm off sick....
# 12   Completed but late in the week due (3 days ne...
# 16   Build is longer than expected with delay due ...
# 14          Scope complete but weekend delivery. jon.
# 15    Complete and awaiting marketing delivery. jon.
# 17               Delivery process started early. jon.

# %%
project_schedule.to_csv("./output/Week19_output.csv")
