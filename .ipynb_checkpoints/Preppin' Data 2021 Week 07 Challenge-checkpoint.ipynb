# %% [markdown]
# ## 2021: Week 7 - Vegan Shopping List
#
# Now that Veganuary has come and gone we thought it would be interesting to take a look at some common supermarket products and use Prep to figure out whether or not they are vegan. Some results may surprise you!
#
# For the sake of this analysis we're taking bee by-products as non-vegan (beeswax, honey, etc).
#
# ### Inputs
#
# 1. A shopping list of products and their ingredients (or allergens when ingredients were not available). I have a child-like palate so its mostly full of sweet treats, some of which you'd expect to be vegan and some of which you'd expect not to be, however everything is commonly found in UK supermarkets so no specialist shops required.
#
# ![img](https://1.bp.blogspot.com/-BfYMo--X7R0/X_RxbJVxzVI/AAAAAAAABDs/yNFOPkii-M8oy4jHtebRFhOt_zQJmJWWwCLcBGAsYHQ/w640-h248/01%2BShoppingListInput.jpg)
#
# 2. Two lists of common non-vegan ingredients and E numbers
#
# ![img2](https://1.bp.blogspot.com/-OKXkRvjBrUQ/X_RxbNpC42I/AAAAAAAABDo/dljP44u8uyMkN_5q4Kw8zUSX_zayCuGQACPcBGAYYCw/w640-h90/02%2BNonVeganIngredients.jpg)
#
# ### Requirments
#
# - Input the data
# - Prepare the keyword data
#     - Add an 'E' in front of every E number.
#     - Stack Animal Ingredients and E Numbers on top of each other.
#     - Get every ingredient and E number onto separate rows.
# - Append the keywords onto the product list.
# - Check whether each product contains any non-vegan ingredients.
# - Prepare a final shopping list of vegan products.
#     - Aggregate the products into vegan and non-vegan.
#     - Filter out the non-vegan products.
# - Prepare a list explaining why the other products aren't vegan.
#     - Keep only non-vegan products.
#     - Duplicate the keyword field.
#     - Rows to columns pivot the keywords using the duplicate as a header.
#     - Write a calculation to concatenate all the keywords into a single comma-separated list for each product, e.g. "whey, milk, egg".
# - Output the data.
#
# ### Outputs
#
# Vegan Shopping List
# - Product
# - Description
# - 20 rows (21 including headers)
#
# ![img3](https://1.bp.blogspot.com/-1WRcHfNPDAc/X_SEXlXvagI/AAAAAAAABD8/VmGKs9tDP1s713EKO1jYSO_yr3Kz-7_YwCLcBGAsYHQ/w400-h271/03%2BVeganOutput.jpg)
#
# Non Vegan List
# - Product
# - Description
# - Contains
# - 19 rows (20 including headers)
#
# ![img4](https://1.bp.blogspot.com/-n90BmuM-xgQ/X_SEe5KydyI/AAAAAAAABEA/uQpiNeQNhCoOT5ntFPgzDZzdbcHQDT8uQCLcBGAsYHQ/w400-h269/04%2BNonVeganOutput.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Input the data

# %%
data = pd.read_excel("./data/Shopping List and Ingredients.xlsx", sheet_name=["Shopping List", "Keywords"])
df = data["Shopping List"].copy()
keywords = data["Keywords"].copy()
keywords
# Out:
#                                   Animal Ingredients  \
# 0  Milk, Whey, Honey, Egg, Lactose, Collagen, Ela...
#
#                                           E Numbers
# 0  120, 441, 545, 901, 904, 910, 920, 921, 913, 966

# %%
df.head()
# Out:
#                                   Product  \
# 0              Tesco Bacon Rashers Snacks
# 1                            Pringles Bbq
# 2  Doritos Chilli Heatwave Tortilla Chips
# 3           Walkers Max Flamin Hot Crisps
# 4            Smiths Frazzles Bacon Snacks
#
#                                          Description  \
# 0  Bacon flavour baked snacks made with maize, ri...
# 1         Texas Barbecue Sauce Flavour Savoury Snack
# 2                 Chilli Heatwave Flavour Corn Chips
# 3  Fiercely Flamin' Hot Flavour Ridged Potato Crisps
# 4                    Crispy Bacon Flavour Corn Snack
#
#                                Ingredients/Allergens
# 0  Maize, Rice Flour, Sunflower Oil, Soya Flour, ...
# 1  Dehydrated Potatoes, Vegetable Oils (Sunflower...
# 2  Corn (Maize), Vegetable Oils (Corn, Sunflower,...
# 3  Potatoes, Vegetable Oils (Sunflower, Rapeseed,...
# 4  Maize, Rapeseed Oil, Bacon Flavour Seasoning [...

# %% [markdown]
# ### Prepare the keyword data 1. Add an 'E' in front of every E number

# %%
e_numbers = keywords["E Numbers"].str.split(",").values
e_numbers = np.concatenate(e_numbers).tolist()

results = []
for num in e_numbers:
    num = num.strip()
    tmp = "E" + num
    results.append(tmp)
e_numbers = results
e_numbers
# Out:
# ['E120',
#  'E441',
#  'E545',
#  'E901',
#  'E904',
#  'E910',
#  'E920',
#  'E921',
#  'E913',
#  'E966']

# %% [markdown]
# ### Stack Animal Ingredients and E Numbers on top of each other

# %%
ingredients = keywords["Animal Ingredients"].str.split(",").values
ingredients = np.concatenate(ingredients).tolist()

results = []
for i in ingredients:
    i = i.strip()
    results.append(i)
ingredients = results
ingredients
# Out:
# ['Milk',
#  'Whey',
#  'Honey',
#  'Egg',
#  'Lactose',
#  'Collagen',
#  'Elastin',
#  'Keratin',
#  'Gelatine',
#  'Gelatin',
#  'Pepsin',
#  'Isinglass',
#  'Shellac',
#  'Lard',
#  'Aspic',
#  'Beeswax']

# %%
global total_ingredients
total_ingredients = ingredients + e_numbers

# %% [markdown]
# ### Check whether each product contains any non-vegan ingredients.

# %%
import re
df["Ingredients_list"] = df["Ingredients/Allergens"].map(lambda ser_: re.sub(r"[{}\[\]()\,]", "", ser_)).str.split(" ")

def check_non_vegan(ser_):
    results = []
    for s in ser_:
        if s in total_ingredients:
            return True
        else :
            pass
    return False

df["Non_vegan"] = df["Ingredients_list"].map(lambda x: check_non_vegan(x))
df.head()
# Out:
#                                   Product  \
# 0              Tesco Bacon Rashers Snacks
# 1                            Pringles Bbq
# 2  Doritos Chilli Heatwave Tortilla Chips
# 3           Walkers Max Flamin Hot Crisps
# 4            Smiths Frazzles Bacon Snacks
#
#                                          Description  \
# 0  Bacon flavour baked snacks made with maize, ri...
# 1         Texas Barbecue Sauce Flavour Savoury Snack
# 2                 Chilli Heatwave Flavour Corn Chips
# 3  Fiercely Flamin' Hot Flavour Ridged Potato Crisps
# 4                    Crispy Bacon Flavour Corn Snack
#
#                                Ingredients/Allergens  \
# 0  Maize, Rice Flour, Sunflower Oil, Soya Flour, ...
# 1  Dehydrated Potatoes, Vegetable Oils (Sunflower...
# 2  Corn (Maize), Vegetable Oils (Corn, Sunflower,...
# 3  Potatoes, Vegetable Oils (Sunflower, Rapeseed,...
# 4  Maize, Rapeseed Oil, Bacon Flavour Seasoning [...
#
#                                     Ingredients_list  Non_vegan
# 0  [Maize, Rice, Flour, Sunflower, Oil, Soya, Flo...      False
# 1  [Dehydrated, Potatoes, Vegetable, Oils, Sunflo...      False
# 2  [Corn, Maize, Vegetable, Oils, Corn, Sunflower...      False
# 3  [Potatoes, Vegetable, Oils, Sunflower, Rapesee...       True
# 4  [Maize, Rapeseed, Oil, Bacon, Flavour, Seasoni...       True

# %% [markdown]
# ### Prepare a final shopping list of vegan products
#  - Aggregate the products into vegan and non-vegan
#  - Filter out the non-vegan products

# %%
vegan_product = df.groupby(["Non_vegan"])[["Product", "Description"]].get_group(False)
vegan_product = vegan_product.reset_index(drop=True)
vegan_product
# Out:
#                                    Product  \
# 0               Tesco Bacon Rashers Snacks
# 1                             Pringles Bbq
# 2   Doritos Chilli Heatwave Tortilla Chips
# 3             Greggs Glazed Ring Doughnuts
# 4        Co-op Bakery 5 Jam Ball Doughnuts
# 5                   Oreos Original Vanilla
# 6    Lotus Biscoff Sandwich Original Cream
# 7          Tesco Dark Chocolate Digestives
# 8              Jammie Dodgers Jam Biscuits
# 9    Cadbury Bourneville Chocolate Fingers
# 10      Green & Blacks Mint Dark Chocolate
# 11  Belvita Soft Filled Chocolate Biscuits
# 12               Graze Cocoa & Vanilla Bar
# 13      Alpen Light Jaffa Cake Cereal Bars
# 14                         Tesco Guacamole
# 15              Nestle Cookie Crisp Cereal
# 16         Nestle Frosted Shreddies Cereal
# 17                   Starburst Fruit Chews
# 18                       Tesco Jelly Beans
# 19               Rowntrees Fruit Pastilles
#
#                                           Description
# 0   Bacon flavour baked snacks made with maize, ri...
# 1          Texas Barbecue Sauce Flavour Savoury Snack
# 2                  Chilli Heatwave Flavour Corn Chips
# 3          A ring doughnut topped with fondant icing.
# 4                                     Jam Doughnut 5s
# 5   Chocolate Flavour Sandwich Biscuits with a Van...
# 6   Caramelised sandwich biscuits with a biscoff c...
# 7    Digestive biscuits half coated in dark chocolate
# 8   Shortcake biscuits with a raspberry flavoured ...
# 9   Crisp biscuits covered with dark chocolate (48...
# 10                     Chocolate with peppermint oil.
# 11  Soft baked biscuits made with wholegrain cerea...
# 12  Wholegrain oat cocoa & vanilla flavoured flapj...
# 13  Mixed cereal bar with orange flavoured fruity ...
# 14  A blend of avocado with tomato, coriander and ...
# 15  Fortified Crispy Wheat and Maize Cereal with C...
# 16  Sugar Frosted Fortified Whole Wheat Malted Cereal
# 17  Chewy Candy with Apple, Orange, Blackcurrant, ...
# 18                Assorted fruit flavour jelly beans.
# 19                                    Fruit Pastilles

# %% [markdown]
# ### Prepare a list explaining why the other products aren't vegan
# - Keep only non-vegan products
# - Duplicate the keywords field
# - Rows to columns pivot the keywords using the duplicate as a header.
# - Write a calculation to concatenate all the keywords into a single comma-separated list for each product, e.g. "whey, milk, egg".

# %%
non_vegan_product = df.groupby(["Non_vegan"])[["Product", "Description", "Ingredients_list"]].get_group(True)
non_vegan_product.shape
# Out:
# (19, 3)

# %%
# Create the function for matching Product Ingredients to Non_vegan ingredients
def contain_non_vegan_ingredients(ser_):
    results = []
    for s in ser_:
        if s in total_ingredients:
            results.append(s)
        else: pass
    return set(results)

# %%
non_vegan_product["Contains"] = non_vegan_product["Ingredients_list"].map(lambda x: contain_non_vegan_ingredients(x))
non_vegan_product["Contains"] = non_vegan_product["Contains"].str.join(",")
non_vegan_product = non_vegan_product.drop("Ingredients_list", axis=1)
non_vegan_product = non_vegan_product.reset_index(drop=True)
non_vegan_product
# Out:
#                                               Product  \
# 0                       Walkers Max Flamin Hot Crisps
# 1                        Smiths Frazzles Bacon Snacks
# 2                        Sensations Thai Sweet Chilli
# 3                          Tesco 5 Pack Jam Doughnuts
# 4              Krispy Kreme Original Glazed Doughnuts
# 5                  Mcvities Dark Chocolate Digestives
# 6                   Tesco Jam Sandwich Creams Biscuit
# 7                           Cadbury Chocolate Fingers
# 8            Lindt Lindor 60% Dark Chocolate Truffles
# 9        Lindt Excellence Mint Intense Dark Chocolate
# 10                  Belvita Soft Bakes Chocolate Chip
# 11  Nature Valley Sweet & Salty Dark Chocolate Wit...
# 12               Alpen Light Summer Fruit Cereal Bars
# 13                                     ASDA Guacamole
# 14                        Tesco Crunchy Cookie Cereal
# 15       Kellogg's Crunchy Nut Peanut Butter Clusters
# 16                             Fruittella Juicy Chews
# 17                                 Haribo Jelly Beans
# 18                                 Maynards Wine Gums
#
#                                           Description            Contains
# 0   Fiercely Flamin' Hot Flavour Ridged Potato Crisps           Milk,Whey
# 1                     Crispy Bacon Flavour Corn Snack   Milk,Lactose,Whey
# 2             Thai Sweet Chilli Flavour Potato Crisps                Milk
# 3                                    Jam Doughnut 5PK                Milk
# 4   Bring some light and fluffy joy into your day ...            Milk,Egg
# 5       Wheatmeal Biscuits Covered in Plain Chocolate                Milk
# 6   Shortcake biscuits sandwiched with a vanilla f...                Milk
# 7   Crisp Biscuits Covered with Cadbury Milk Choco...                Milk
# 8   Extra dark chocolate with a smooth melting fil...        Milk,Lactose
# 9   Fine dark chocolate with an intense taste of mint                Milk
# 10  Soft baked biscuits made with wholegrain cerea...                Milk
# 11  Chewy peanut, almond and oat bar with dark cho...  Milk,Honey,Lactose
# 12  Mixed cereal bar with apple, sweetened cranber...        Milk,Lactose
# 13  Avocado dip with double cream, tomatoes, lime ...                Milk
# 14  Chocolate flavoured wheat and maize cereal for...                Milk
# 15             Oat, Maize, Wheat and Peanut Clusters.                Milk
# 16  Assorted Chewy Sweets with Strawberry, Orange ...            Gelatine
# 17                 Assorted Flavour Sugar Coated Gums             Beeswax
# 18                                Fruit flavour gums.            Gelatine

# %%
vegan_product.to_csv("./output/Week7_output_1.csv")
non_vegan_product.to_csv("./output/Week7_output_2.csv")
