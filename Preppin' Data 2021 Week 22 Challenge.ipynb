# %% [markdown]
# ## 2021: Week 22 - Answer Smash
#
# Recently, my family and I have become quite invested in the TV quiz show Richard Osman's House of Games. The final round is always a round called Answer Smash. In this round you have a picture and question and you have to "smash" the name of the picture with the answer to the question, as per the below example.
#
# ![img](https://lh3.googleusercontent.com/-x16G24LFxik/YJzZMfUFdVI/AAAAAAAAAzQ/oDI1lOo9RA4ut-jVWFs7CfbS_z_-tSg4wCLcBGAsYHQ/w400-h244/image.png)
#
# I thought it would be fun to work backwards and have a list of answer smashes from which we have to extract the Preppin' participant and the answer to the question!
#
# ### Input
# 1. Answer Smash list
# ![img](https://lh3.googleusercontent.com/-KPicq8d9jII/YJzbkRtRfOI/AAAAAAAAAzs/vZIaiRcWhhw1Lt8StK1zMc1cQ1IWbZvggCLcBGAsYHQ/image.png)
#
# 2. Names
# ![img](https://lh3.googleusercontent.com/-VZX54rgmlfM/YJzbPjM8y7I/AAAAAAAAAzc/LrY4ELLbV8MBJwGlhisTzsAQLEzpc9PwQCLcBGAsYHQ/image.png)
#
# 3. Questions
# ![img](https://lh3.googleusercontent.com/--6TUf8nijQE/YJzbZpziTsI/AAAAAAAAAzk/49dxzz-tQVE5KvaVY1C1wiZ18ogqHI3bQCLcBGAsYHQ/image.png)
#
# 4. Categories
# ![img](https://lh3.googleusercontent.com/-MfV11JywIiQ/YJzbx-Y8knI/AAAAAAAAAz0/V6VOAAY7IYs0JeV-TOsJMRtVgTcYcy75gCLcBGAsYHQ/image.png)
#
# ### Requirement
# - Input the data
# - The category dataset requires some cleaning so that Category and Answer are 2 separate fields (hint)
# - Join the datasets together, making sure to keep an eye on row counts (hint)
# - Filter the data so that each answer smash is matched with the corresponding name and answer (hint)
# - Remove unnecessary columns
# - Output the data
#
# ### Output
# ![img](https://lh3.googleusercontent.com/-e14km_tdnKs/YJzec7yMlsI/AAAAAAAAA0A/LrCd7oXn318CwVXWEj3S0W4aRyr65P5QwCLcBGAsYHQ/w640-h130/image.png)
#
# - 5 fields
#     - Q No
#     - Name
#     - Question
#     - Answer
#     - Answer Smash
# - 20 rows (21 including headers)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Input the data

# %%
data = pd.read_excel("./data/Answer Smash Input.xlsx", sheet_name=["Answer Smash", "Names",
                                                                   "Questions", "Category"])

# %%
answers = data["Answer Smash"].copy()
names = data["Names"].copy()
questions = data["Questions"].copy()
categories = data["Category"].copy()

# %%
### The category dataset requires some cleaning so that Category and Answer are 2 separate fields

# %%
categories["Category"] = categories["Category: Answer"].map(lambda x: x.split(":")[0].strip())
categories["Answer"] = categories["Category: Answer"].map(lambda x: x.split(":")[1].strip())
categories = categories.drop("Category: Answer", axis=1)
categories
# Out:
#       Category                     Answer
# 0      Animals                   Aardvark
# 1    Companies                     Amazon
# 2    Companies        Annies Burger Shack
# 3      Science               Astrophysics
# 4    Companies             Barnes & Noble
# 5   Characters             Bert and Ernie
# 6   Characters                   Big bird
# 7      Science                      Brain
# 8      Animals                 Brown Bear
# 9    Companies              Byron Burgers
# 10  Characters  Casper the friendly ghost
# 11     Animals                 Chinchilla
# 12        Food                   Coleslaw
# 13     Animals                    Dolphin
# 14     Science               Energy units
# 15   Companies               Evans Cycles
# 16     Animals                      Gecko
# 17        Food                    Gherkin
# 18   Companies                   Halfords
# 19        Food                  Hot Sauce
# 20        Food                    Ketchup
# 21        Food                     Kimchi
# 22     Science                Lymph nodes
# 23        Food                 Mayonnaise
# 24  Characters       Nearly Headless Nick
# 25  Characters               Norman Bates
# 26  Characters               Peter Parker
# 27     Science             Photosynthesis
# 28     Animals                 Polar Bear
# 29        Food                      Salad
# 30     Animals                   Seahorse
# 31     Animals               Snow leopard
# 32   Companies                      Tesco
# 33     Animals                      Tiger
# 34  Characters                 Tony Stark
# 35        Food                      Unagi
# 36   Companies                    Wayfair

# %%
### Join the datasets together, making sure to keep an eye on row counts (hint)

# %%
answer_name = pd.concat([answers, names], axis=1)
answer_name
# Out:
#     Q No                             Answer Smash  \
# 0      1                       Mo Hassnow leopard
# 1      2                  Kelly Gilbert and ernie
# 2      3                          Arsenergy units
# 3      4                Nicolas Mieszalymph nodes
# 4      5  Amalia García-Vellido Santíastrophysics
# 5      6                      Owen Barnes & Noble
# 6      7                       Simon Evans Cycles
# 7      8                           Donna Coleslaw
# 8      9                       Will Suttony Stark
# 9     10                       Shahzad Ziaardvark
# 10    11                        Nik Eveleigherkin
# 11    12                 Jorge Supelanorman Bates
# 12    13                         Tom Prowseahorse
# 13    14                       Carl Allchinchilla
# 14    15              Jonathan Allenbyron Burgers
# 15    16                          Rosario Gaunagi
# 16    17          Pat Lucasper the Friendly Ghost
# 17    18                     Michael Heighwayfair
# 18    19                          Kate Brown Bear
# 19    20                         Vivien Hot Sauce
#
#                              Name
# 0                        Mo Hassn
# 1                   Kelly Gilbert
# 2                          Arsene
# 3                Nicolas Mieszaly
# 4   Amalia García-Vellido Santías
# 5                     Owen Barnes
# 6                     Simon Evans
# 7                     Donna Coles
# 8                     Will Sutton
# 9                     Shahzad Zia
# 10                   Nik Eveleigh
# 11                 Jorge Supelano
# 12                     Tom Prowse
# 13                   Carl Allchin
# 14               Jonathan Allenby
# 15                  Rosario Gauna
# 16                      Pat Lucas
# 17               Michael Heighway
# 18                     Kate Brown
# 19                      Vivien Ho

# %%
df = answer_name.merge(questions, how="inner", on="Q No")
df
# Out:
#     Q No                             Answer Smash  \
# 0      1                       Mo Hassnow leopard
# 1      2                  Kelly Gilbert and ernie
# 2      3                          Arsenergy units
# 3      4                Nicolas Mieszalymph nodes
# 4      5  Amalia García-Vellido Santíastrophysics
# 5      6                      Owen Barnes & Noble
# 6      7                       Simon Evans Cycles
# 7      8                           Donna Coleslaw
# 8      9                       Will Suttony Stark
# 9     10                       Shahzad Ziaardvark
# 10    11                        Nik Eveleigherkin
# 11    12                 Jorge Supelanorman Bates
# 12    13                         Tom Prowseahorse
# 13    14                       Carl Allchinchilla
# 14    15              Jonathan Allenbyron Burgers
# 15    16                          Rosario Gaunagi
# 16    17          Pat Lucasper the Friendly Ghost
# 17    18                     Michael Heighwayfair
# 18    19                          Kate Brown Bear
# 19    20                         Vivien Hot Sauce
#
#                              Name    Category  \
# 0                        Mo Hassn     Animals
# 1                   Kelly Gilbert  Characters
# 2                          Arsene     Science
# 3                Nicolas Mieszaly     Science
# 4   Amalia García-Vellido Santías     Science
# 5                     Owen Barnes   Companies
# 6                     Simon Evans   Companies
# 7                     Donna Coles        Food
# 8                     Will Sutton  Characters
# 9                     Shahzad Zia     Animals
# 10                   Nik Eveleigh        Food
# 11                 Jorge Supelano  Characters
# 12                     Tom Prowse     Animals
# 13                   Carl Allchin     Animals
# 14               Jonathan Allenby   Companies
# 15                  Rosario Gauna        Food
# 16                      Pat Lucas  Characters
# 17               Michael Heighway   Companies
# 18                     Kate Brown     Animals
# 19                      Vivien Ho        Food
#
#                                              Question
# 0     Which mammal has the latin name panthera uncia?
# 1                  Name the famous Sesame Street duo.
# 2            What are joules or therms an example of?
# 3   What parts of the body contain immune cells to...
# 4   Which branch of space science applies the laws...
# 5   What's the name of the American bookseller fou...
# 6   Which British cycle retailer was founded in 1921?
# 7   Which side dish consists mainly of shredded ra...
# 8   Who is the a genius, billionaire, playboy, phi...
# 9   Which animal is frequently confused with the a...
# 10        What's another word for a pickled cucumber?
# 11      Who's the main antagonist in the film Psycho?
# 12  In which fish species is it the males who get ...
# 13  Which rodents are slightly larger than squirre...
# 14    Which British burger chain was founded in 2007?
# 15       What's the japanese word for freshwater eel?
# 16  Which ghost is often criticised by his 3 wicke...
# 17  Which American company selling furniture was f...
# 18      Which animal has the latin name Ursus arctos?
# 19  Which condiment is mostly made from chilli pep...

# %%
### Filter the data so that each answer smash is matched with the corresponding name and answer

# %%
categories
# Out:
#       Category                     Answer
# 0      Animals                   Aardvark
# 1    Companies                     Amazon
# 2    Companies        Annies Burger Shack
# 3      Science               Astrophysics
# 4    Companies             Barnes & Noble
# 5   Characters             Bert and Ernie
# 6   Characters                   Big bird
# 7      Science                      Brain
# 8      Animals                 Brown Bear
# 9    Companies              Byron Burgers
# 10  Characters  Casper the friendly ghost
# 11     Animals                 Chinchilla
# 12        Food                   Coleslaw
# 13     Animals                    Dolphin
# 14     Science               Energy units
# 15   Companies               Evans Cycles
# 16     Animals                      Gecko
# 17        Food                    Gherkin
# 18   Companies                   Halfords
# 19        Food                  Hot Sauce
# 20        Food                    Ketchup
# 21        Food                     Kimchi
# 22     Science                Lymph nodes
# 23        Food                 Mayonnaise
# 24  Characters       Nearly Headless Nick
# 25  Characters               Norman Bates
# 26  Characters               Peter Parker
# 27     Science             Photosynthesis
# 28     Animals                 Polar Bear
# 29        Food                      Salad
# 30     Animals                   Seahorse
# 31     Animals               Snow leopard
# 32   Companies                      Tesco
# 33     Animals                      Tiger
# 34  Characters                 Tony Stark
# 35        Food                      Unagi
# 36   Companies                    Wayfair

# %%
import re

results = []
for i in list_of_answers:
    tmp_list = df["Answer Smash"].map(lambda x: re.findall(i, x, flags=re.IGNORECASE))
    tmp_list = tmp_list.map(lambda x: np.nan if len(x) == 0 else x)
    results.append(tmp_list)
results = pd.concat(results, axis=1).dropna(how="all", axis=1)
results
# Out:
#    Answer Smash    Answer Smash      Answer Smash      Answer Smash  \
# 0           NaN             NaN               NaN               NaN
# 1           NaN             NaN               NaN  [bert and ernie]
# 2           NaN             NaN               NaN               NaN
# 3           NaN             NaN               NaN               NaN
# 4           NaN  [astrophysics]               NaN               NaN
# 5           NaN             NaN  [Barnes & Noble]               NaN
# 6           NaN             NaN               NaN               NaN
# 7           NaN             NaN               NaN               NaN
# 8           NaN             NaN               NaN               NaN
# 9    [aardvark]             NaN               NaN               NaN
# 10          NaN             NaN               NaN               NaN
# 11          NaN             NaN               NaN               NaN
# 12          NaN             NaN               NaN               NaN
# 13          NaN             NaN               NaN               NaN
# 14          NaN             NaN               NaN               NaN
# 15          NaN             NaN               NaN               NaN
# 16          NaN             NaN               NaN               NaN
# 17          NaN             NaN               NaN               NaN
# 18          NaN             NaN               NaN               NaN
# 19          NaN             NaN               NaN               NaN
#
#     Answer Smash     Answer Smash                 Answer Smash  Answer Smash  \
# 0            NaN              NaN                          NaN           NaN
# 1            NaN              NaN                          NaN           NaN
# 2            NaN              NaN                          NaN           NaN
# 3            NaN              NaN                          NaN           NaN
# 4            NaN              NaN                          NaN           NaN
# 5            NaN              NaN                          NaN           NaN
# 6            NaN              NaN                          NaN           NaN
# 7            NaN              NaN                          NaN           NaN
# 8            NaN              NaN                          NaN           NaN
# 9            NaN              NaN                          NaN           NaN
# 10           NaN              NaN                          NaN           NaN
# 11           NaN              NaN                          NaN           NaN
# 12           NaN              NaN                          NaN           NaN
# 13           NaN              NaN                          NaN  [chinchilla]
# 14           NaN  [byron Burgers]                          NaN           NaN
# 15           NaN              NaN                          NaN           NaN
# 16           NaN              NaN  [casper the Friendly Ghost]           NaN
# 17           NaN              NaN                          NaN           NaN
# 18  [Brown Bear]              NaN                          NaN           NaN
# 19           NaN              NaN                          NaN           NaN
#
#    Answer Smash    Answer Smash    Answer Smash Answer Smash Answer Smash  \
# 0           NaN             NaN             NaN          NaN          NaN
# 1           NaN             NaN             NaN          NaN          NaN
# 2           NaN  [energy units]             NaN          NaN          NaN
# 3           NaN             NaN             NaN          NaN          NaN
# 4           NaN             NaN             NaN          NaN          NaN
# 5           NaN             NaN             NaN          NaN          NaN
# 6           NaN             NaN  [Evans Cycles]          NaN          NaN
# 7    [Coleslaw]             NaN             NaN          NaN          NaN
# 8           NaN             NaN             NaN          NaN          NaN
# 9           NaN             NaN             NaN          NaN          NaN
# 10          NaN             NaN             NaN    [gherkin]          NaN
# 11          NaN             NaN             NaN          NaN          NaN
# 12          NaN             NaN             NaN          NaN          NaN
# 13          NaN             NaN             NaN          NaN          NaN
# 14          NaN             NaN             NaN          NaN          NaN
# 15          NaN             NaN             NaN          NaN          NaN
# 16          NaN             NaN             NaN          NaN          NaN
# 17          NaN             NaN             NaN          NaN          NaN
# 18          NaN             NaN             NaN          NaN          NaN
# 19          NaN             NaN             NaN          NaN  [Hot Sauce]
#
#      Answer Smash    Answer Smash Answer Smash    Answer Smash  Answer Smash  \
# 0             NaN             NaN          NaN  [snow leopard]           NaN
# 1             NaN             NaN          NaN             NaN           NaN
# 2             NaN             NaN          NaN             NaN           NaN
# 3   [lymph nodes]             NaN          NaN             NaN           NaN
# 4             NaN             NaN          NaN             NaN           NaN
# 5             NaN             NaN          NaN             NaN           NaN
# 6             NaN             NaN          NaN             NaN           NaN
# 7             NaN             NaN          NaN             NaN           NaN
# 8             NaN             NaN          NaN             NaN  [tony Stark]
# 9             NaN             NaN          NaN             NaN           NaN
# 10            NaN             NaN          NaN             NaN           NaN
# 11            NaN  [norman Bates]          NaN             NaN           NaN
# 12            NaN             NaN   [seahorse]             NaN           NaN
# 13            NaN             NaN          NaN             NaN           NaN
# 14            NaN             NaN          NaN             NaN           NaN
# 15            NaN             NaN          NaN             NaN           NaN
# 16            NaN             NaN          NaN             NaN           NaN
# 17            NaN             NaN          NaN             NaN           NaN
# 18            NaN             NaN          NaN             NaN           NaN
# 19            NaN             NaN          NaN             NaN           NaN
#
#    Answer Smash Answer Smash
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6           NaN          NaN
# 7           NaN          NaN
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13          NaN          NaN
# 14          NaN          NaN
# 15      [unagi]          NaN
# 16          NaN          NaN
# 17          NaN    [wayfair]
# 18          NaN          NaN
# 19          NaN          NaN

# %%
test = []
for i in np.arange(len(results.columns)):
    tmp = results.iloc[:, i].dropna()
    test.append(tmp)
test = pd.concat(test)
test = pd.Series(test)
test = test.map(lambda x: x[0])
test = test.str.capitalize()
test
# Out:
# 9                      Aardvark
# 4                  Astrophysics
# 5                Barnes & noble
# 1                Bert and ernie
# 18                   Brown bear
# 14                Byron burgers
# 16    Casper the friendly ghost
# 13                   Chinchilla
# 7                      Coleslaw
# 2                  Energy units
# 6                  Evans cycles
# 10                      Gherkin
# 19                    Hot sauce
# 3                   Lymph nodes
# 11                 Norman bates
# 12                     Seahorse
# 0                  Snow leopard
# 8                    Tony stark
# 15                        Unagi
# 17                      Wayfair
# Name: Answer Smash, dtype: object

# %%
df.join(test, how="inner", rsuffix="_y").rename(columns={"Answer Smash_y": "Answer"})
# Out:
#     Q No                             Answer Smash  \
# 0      1                       Mo Hassnow leopard
# 1      2                  Kelly Gilbert and ernie
# 2      3                          Arsenergy units
# 3      4                Nicolas Mieszalymph nodes
# 4      5  Amalia García-Vellido Santíastrophysics
# 5      6                      Owen Barnes & Noble
# 6      7                       Simon Evans Cycles
# 7      8                           Donna Coleslaw
# 8      9                       Will Suttony Stark
# 9     10                       Shahzad Ziaardvark
# 10    11                        Nik Eveleigherkin
# 11    12                 Jorge Supelanorman Bates
# 12    13                         Tom Prowseahorse
# 13    14                       Carl Allchinchilla
# 14    15              Jonathan Allenbyron Burgers
# 15    16                          Rosario Gaunagi
# 16    17          Pat Lucasper the Friendly Ghost
# 17    18                     Michael Heighwayfair
# 18    19                          Kate Brown Bear
# 19    20                         Vivien Hot Sauce
#
#                              Name    Category  \
# 0                        Mo Hassn     Animals
# 1                   Kelly Gilbert  Characters
# 2                          Arsene     Science
# 3                Nicolas Mieszaly     Science
# 4   Amalia García-Vellido Santías     Science
# 5                     Owen Barnes   Companies
# 6                     Simon Evans   Companies
# 7                     Donna Coles        Food
# 8                     Will Sutton  Characters
# 9                     Shahzad Zia     Animals
# 10                   Nik Eveleigh        Food
# 11                 Jorge Supelano  Characters
# 12                     Tom Prowse     Animals
# 13                   Carl Allchin     Animals
# 14               Jonathan Allenby   Companies
# 15                  Rosario Gauna        Food
# 16                      Pat Lucas  Characters
# 17               Michael Heighway   Companies
# 18                     Kate Brown     Animals
# 19                      Vivien Ho        Food
#
#                                              Question  \
# 0     Which mammal has the latin name panthera uncia?
# 1                  Name the famous Sesame Street duo.
# 2            What are joules or therms an example of?
# 3   What parts of the body contain immune cells to...
# 4   Which branch of space science applies the laws...
# 5   What's the name of the American bookseller fou...
# 6   Which British cycle retailer was founded in 1921?
# 7   Which side dish consists mainly of shredded ra...
# 8   Who is the a genius, billionaire, playboy, phi...
# 9   Which animal is frequently confused with the a...
# 10        What's another word for a pickled cucumber?
# 11      Who's the main antagonist in the film Psycho?
# 12  In which fish species is it the males who get ...
# 13  Which rodents are slightly larger than squirre...
# 14    Which British burger chain was founded in 2007?
# 15       What's the japanese word for freshwater eel?
# 16  Which ghost is often criticised by his 3 wicke...
# 17  Which American company selling furniture was f...
# 18      Which animal has the latin name Ursus arctos?
# 19  Which condiment is mostly made from chilli pep...
#
#                        Answer
# 0                Snow leopard
# 1              Bert and ernie
# 2                Energy units
# 3                 Lymph nodes
# 4                Astrophysics
# 5              Barnes & noble
# 6                Evans cycles
# 7                    Coleslaw
# 8                  Tony stark
# 9                    Aardvark
# 10                    Gherkin
# 11               Norman bates
# 12                   Seahorse
# 13                 Chinchilla
# 14              Byron burgers
# 15                      Unagi
# 16  Casper the friendly ghost
# 17                    Wayfair
# 18                 Brown bear
# 19                  Hot sauce
