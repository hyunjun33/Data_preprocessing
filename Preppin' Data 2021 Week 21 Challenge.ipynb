# %% [markdown]
# ## 2021: Week 21 Getting Trolleyed
#
# Our final challenge for calculations month is all about the Analytical Calculations in Tableau Prep, Level of Detail calculations and Rankings. These calculations let you answer the questions your stakeholders have before you've even visualised anything. Sometimes all we need is the answer. If you're not using Prep for this challenge, I have hopefully made a challenge you can replicate too (you might just need to use a join).
#
# ### Challenge
# With the Prep Air - New Trolley Inventory project finally delivered at the end of May, we want to analyse what are the products that we are now selling for a much higher amount than we did before the project. We want to analyse the top three products based on price rise per destination.
#
# ### Input
# One spreadsheet with 10 sheets, one sheet per month (Jan is month 1, Feb is month 2 etc)
#
# ![img](https://1.bp.blogspot.com/-KkflvnUjLZU/YKvdxeHrXVI/AAAAAAAACLU/c9omraL8U5AhyH8u6A-yFphCvXCxYvU9gCLcBGAsYHQ/w640-h150/Screenshot%2B2021-05-24%2Bat%2B18.09.04.png)
#
# ### Requirements
# - Input data
# - Bring all the sheets together
# - Use the Day of Month and Table Names (sheet name in other tools) to form a date field for the purchase called 'Date'
# - Create 'New Trolley Inventory?' field to show whether the purchase was made on or after 1st June 2021 (the first date with the revised inventory after the project closed)
# - Remove lots of the detail of the product name:
#     - Only return any names before the '-' (hyphen)
#     - If a product doesn't have a hyphen return the full product name
# - Make price a numeric field
# - Work out the average selling price per product
# - Workout the Variance (difference) between the selling price and the average selling price
# - Rank the Variances (1 being the largest positive variance) per destination and whether the product was sold before or after the new trolley inventory project delivery
# - Return only ranks 1-5
# - Output the data
#
# ### Output
# We want to know which two products appeared more than once in the rankings and whether they were sold before or after the project delivery. Tweet us your answer!
#
# ![img](https://1.bp.blogspot.com/-NTuxXrdAUSU/YKvjS3y9jBI/AAAAAAAACLc/5T643zvPbf8G7NeS3k24uXhCwtKGsGKfQCLcBGAsYHQ/w640-h122/Screenshot%2B2021-05-24%2Bat%2B18.32.40.png)
#
# One file:
# 11 fields:
# - New Trolley Inventory
# - Variance Rank by Destination (remember this also factors in the pre / post project delivery)
# - Variance
# - Average Price per Product
# - Date
# - Product
# - First name
# - Last Name
# - Email
# - Price
# - Destination
#
# 50 rows (51 rows including headers)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Input data

# %%
data = pd.read_excel("./data/PD 2021 Wk 21 Input.xlsx", sheet_name=["Month 1", "Month 2", "Month 3", "Month 4", "Month 5",
                                                                    "Month 6", "Month 7", "Month 8", "Month 9", "Month 10"])

# %%
### Bring all the sheets together

# %%
files = []
for i in range(1, 11):
    file_name = "Month " + str(i)
    file = data[file_name].copy()
    files.append(file)

# %% [markdown]
# ### Use the Day of Month and Table Names (sheet name in other tools) to form a date field for the purchase called 'Date'

# %%
for i in range(1, 11):
    files[i-1].loc[:, "Year"] = 2021
    files[i-1].loc[:, "Month"] = i
    files[i-1].loc[:, "Day of Month"] = files[i-1].loc[:, "Day of Month"].astype(int)

# %%
for i in range(0, 10):
    date = files[i].apply(lambda df_: str(df_["Year"]) + "/" + str(df_["Month"]) + "/" + str(df_["Day of Month"]), axis=1)
    files[i].loc[:, "Date"] = pd.to_datetime(date, format="%Y/%m/%d")

# %%
df = pd.concat(files, axis=0)
df.shape
# Out:
# (10000, 10)

# %% [markdown]
# ### Create 'New Trolley Inventory?' field to show whether the purchase was made on or after 1st June 2021 (the first date with the revised inventory after the project closed)

# %%
df.loc[:, "New Trolley Inventory?"] = False
df.loc[df["Date"] >= "2021-06-01", "New Trolley Inventory?"] = True

# %% [markdown]
# ### Remove lots of the detail of the product name:
# - Only return any names before the '-' (hyphen)
# - If a product doesn't have a hyphen return the full product name

# %%
df.head()
# Out:
#    Day of Month first_name last_name                       email  \
# 0             9     Daffie   Clemont           dclemont0@unc.edu
# 1            19      Lucio   Muzzall          lmuzzall1@dell.com
# 2            25     Corbie  Shrigley  cshrigley2@sourceforge.net
# 3             9      Sioux     Couth        scouth3@bluehost.com
# 4            21     Almira  Rickards      arickards4@godaddy.com
#
#                    Product   Price Destination  Year  Month       Date  \
# 0               Emulsifier  $10.14  New York    2021      1 2021-01-09
# 1           Chambord Royal  $33.89      London  2021      1 2021-01-19
# 2  Apples - Sliced / Wedge   $1.64       Perth  2021      1 2021-01-25
# 3     Vinegar - White Wine  $19.84       Paris  2021      1 2021-01-09
# 4    Food Colouring - Pink  $20.15   Edinburgh  2021      1 2021-01-21
#
#    New Trolley Inventory?
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False

# %%
import re
def product_name_preprocessing(df_):
    index_true = df_["Product"].map(lambda x: bool(re.findall(r"[-]+", x)))
    df_.loc[index_true, "Product"] = df_.loc[index_true, "Product"].map(lambda x: x.split("-")[0])
    return df_

# %%
df = product_name_preprocessing(df)
df["Product"].value_counts()
# Out:
# Wine                        692
# Cheese                      296
# Bread                       265
# Soup                        194
# Beef                        179
#                            ...
# Soup Bowl Clear 8oz92008      1
# Ham Black Forest              1
# Iced Tea Concentrate          1
# Maple Syrup                   1
# Creme De Cacao Mcguines       1
# Name: Product, Length: 1028, dtype: int64

# %% [markdown]
# ### Make price a numeric field

# %%
df["Price"] = df["Price"].str.replace("$", "").astype(float)
# Out:
# C:\Users\HYUNJUN\anaconda3\envs\deep-learning-gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Work out the average selling price per product

# %%
group_avg = df.groupby(["Product"])["Price"].mean()
group_avg
# Out:
# Product
# 7up Diet, 355 Ml      27.690000
# Absolut Citron        23.888000
# Alize Gold Passion    18.872000
# Alize Red Passion     27.090000
# Alize Sunset          19.880000
#                         ...
# Yoplait               29.397500
# Yoplait Drink         15.756667
# Yucca                 19.820000
# Yukon Jack            26.597500
# Zucchini              24.514444
# Name: Price, Length: 1028, dtype: float64

# %% [markdown]
# ### Workout the Variance (difference) between the selling price and the average selling price

# %%
df = df.merge(group_avg, how="left", left_on="Product", right_on=group_avg.index).rename(columns={"Price_x" : "Price",
                                                                                                  "Price_y" : "Avg Price per Product"})
df["Variance"] = abs(df["Price"] - df["Avg Price per Product"])
df.head()
# Out:
#    Day of Month first_name last_name                       email  \
# 0             9     Daffie   Clemont           dclemont0@unc.edu
# 1            19      Lucio   Muzzall          lmuzzall1@dell.com
# 2            25     Corbie  Shrigley  cshrigley2@sourceforge.net
# 3             9      Sioux     Couth        scouth3@bluehost.com
# 4            21     Almira  Rickards      arickards4@godaddy.com
#
#            Product  Price Destination  Year  Month       Date  \
# 0       Emulsifier  10.14  New York    2021      1 2021-01-09
# 1   Chambord Royal  33.89      London  2021      1 2021-01-19
# 2          Apples    1.64       Perth  2021      1 2021-01-25
# 3         Vinegar   19.84       Paris  2021      1 2021-01-09
# 4  Food Colouring   20.15   Edinburgh  2021      1 2021-01-21
#
#    New Trolley Inventory?  Avg Price per Product   Variance
# 0                   False              21.600000  11.460000
# 1                   False              16.034000  17.856000
# 2                   False              19.782000  18.142000
# 3                   False              23.054821   3.214821
# 4                   False              26.033333   5.883333

# %% [markdown]
# ### Rank the Variances (1 being the largest positive variance) per destination and whether the product was sold before or after the new trolley inventory project delivery

# %%
df["Destination"] = df["Destination"].str.strip()
grouped = df.groupby(["Destination"])

# %%
grouped.indices.keys()
# Out:
# dict_keys(['Edinburgh', 'London', 'New York', 'Paris', 'Perth'])

# %%
rank = df.groupby(["Destination", "New Trolley Inventory?"])["Variance"].rank(method="dense", ascending=False).astype(int)
df["Rank"] = rank

# %%
output = df[df["Rank"].isin([1, 2, 3, 4, 5])]
output = output.reset_index(drop=True)
output.shape
# Out:
# (50, 14)

# %%
# Out:
#     Day of Month   first_name    last_name                             email  \
# 34            30       Kylynn       Goudge       kgoudge53@howstuffworks.com
# 21             2         Lalo        Creek            lcreekf2@cafepress.com
# 45            23    Cornelius       Horney        chorneyds@seattletimes.com
# 28             3       Martyn         Dace                   mdace2l@soup.io
# 4             22      Fairfax       Raikes             fraikesox@twitpic.com
# 5             19     Batsheva        Healy                     bhealyj@51.la
# 41             9          Lyn   Rubinowitz             lrubinowitzjz@usa.gov
# 7             20         Glyn       Kervin          gkervin4i@infoseek.co.jp
# 32            18      Gunther      Stowell             gstowellj@histats.com
# 14             1        Gerek      Flanner               gflanner1a@usgs.gov
# 29            26       Janeva      Loxston           jloxston4s@hubpages.com
# 30            17       Magnum      Ainslee           mainsleeaz@springer.com
# 17            16      Alexine    Sandbrook            asandbrookld@google.es
# 16             9     Salomone       Bowhay     sbowhay5p@constantcontact.com
# 15            16      Morgana      Hurrell        mhurrell50@photobucket.com
# 24            15       Enrico   Lanchberry    elanchberryje@businessweek.com
# 40            10       Putnam       Fontin               pfontinjb@salon.com
# 8              2     Gloriana     Fullwood             gfullwoodaz@ameblo.jp
# 25            15        Dione      Morales          dmorales5m@posterous.com
# 48             5         Gray      Battrum               gbattrumie@java.com
# 38            27          Joe  Clericoates             jclericoatesc9@gov.uk
# 39            17        Zarah         Tyce                ztycei2@senate.gov
# 43            25        Izaak      Pasmore               ipasmore1w@ehow.com
# 46            10         Yvor      Smerdon              ysmerdonhr@imgur.com
# 27            12      Damiano        Mouan            dmouanq7@woothemes.com
# 0              9       Kizzie    Bruggeman        kbruggemanq@thetimes.co.uk
# 9             15         Erin        Perle                 eperled7@ucla.edu
# 20            10      Andreas      Berthot            aberthotqd@latimes.com
# 18             1         Otto      O'Nolan              oonolanod@unesco.org
# 13             2        Benni         Caff               bcaffgy@auda.org.au
# 12            28      Eleanor     MacAulay             emacaulayfo@google.es
# 2              7      Ingemar      Burgiss      iburgissbp@howstuffworks.com
# 36            20      Othello       Dudson             odudson86@addthis.com
# 35            25        Corry        Dalli              cdalli5z@gizmodo.com
# 42             9      Marleah    Phillippo  mphillippom2@creativecommons.org
# 33            26         Vite      Airdrie           vairdrie4y@netvibes.com
# 47             6    Millisent       Patria       mpatriahu@howstuffworks.com
# 19            12     Valencia   Regenhardt             vregenhardtpf@mtv.com
# 22            29      Othello       Newall         onewallhj@theguardian.com
# 3             23    Catherina        Eymer             ceymere6@facebook.com
# 1             19       Leslie     Streight                lstreight22@ed.gov
# 44            18       Luther      Maiklem             lmaiklem6t@nature.com
# 26            14    Gualterio        Barks            gbarksbd@angelfire.com
# 37             3       Willow     Chapelle        wchapelle9q@deviantart.com
# 10            12       Sallie      Wharton                 swhartoni1@si.edu
# 11            18        Hymie      McAllen             hmcallenam@reddit.com
# 23             9     Carleton       Worsam            cworsamic@linkedin.com
# 31            23     Veronika  Fitzsymonds            vfitzsymondsr0@hud.gov
# 6             14      Matthus    Phinnessy          mphinnessy38@weather.com
# 49             3  Jacquenetta       Norres            jnorresr6@geocities.jp
#
#                   Product  Price Destination  Year  Month       Date  \
# 34                  Milk   59.47   Edinburgh  2021      9 2021-09-30
# 21        Food Colouring    1.07   Edinburgh  2021      5 2021-05-02
# 45                 Puree   54.58   Edinburgh  2021     10 2021-10-23
# 28                  Beer   57.19   Edinburgh  2021      8 2021-08-03
# 4                 Rabbit    1.15   Edinburgh  2021      1 2021-01-22
# 5                  Pears    3.29   Edinburgh  2021      2 2021-02-19
# 41                  Wine   58.65   Edinburgh  2021      9 2021-09-09
# 7                Sausage    2.39   Edinburgh  2021      2 2021-02-20
# 32                  Wine   59.31   Edinburgh  2021      9 2021-09-18
# 14                 Capon    0.24   Edinburgh  2021      4 2021-04-01
# 29             Macaroons   54.81      London  2021      8 2021-08-26
# 30               Spinach   59.64      London  2021      8 2021-08-17
# 17            Artichokes    0.65      London  2021      4 2021-04-16
# 16             Coriander    2.76      London  2021      4 2021-04-09
# 15                 Honey    1.51      London  2021      4 2021-04-16
# 24              Magnotta    0.63      London  2021      5 2021-05-15
# 40     Beef Ground Medium  58.26      London  2021      9 2021-09-10
# 8                   Dikon   1.48      London  2021      2 2021-02-02
# 25                  Cake   58.33      London  2021      7 2021-07-15
# 48     Alize Gold Passion  55.98      London  2021     10 2021-10-05
# 38               Oranges   54.18    New York  2021      9 2021-09-27
# 39                   Tea   59.83    New York  2021      9 2021-09-17
# 43         Chicken Thigh   59.31    New York  2021     10 2021-10-25
# 46                Pastry   59.34    New York  2021     10 2021-10-10
# 27          Island Oasis   59.14    New York  2021      7 2021-07-12
# 0               Foil Wrap   0.91    New York  2021      1 2021-01-09
# 9     Bread Roll Foccacia   4.24    New York  2021      2 2021-02-15
# 20               Ostrich    0.02    New York  2021      4 2021-04-10
# 18                 Olive    1.05    New York  2021      4 2021-04-01
# 13                 Honey    0.16    New York  2021      3 2021-03-02
# 12                   Sun    0.32       Paris  2021      3 2021-03-28
# 2          Black Currants   2.91       Paris  2021      1 2021-01-07
# 36                Pastry   58.94       Paris  2021      9 2021-09-20
# 35                Longos   59.75       Paris  2021      9 2021-09-25
# 42           Swiss Chard   58.78       Paris  2021      9 2021-09-09
# 33           Tart Shells   59.86       Paris  2021      9 2021-09-26
# 47             Appetizer   58.17       Paris  2021     10 2021-10-06
# 19      Assorted Desserts   3.10       Paris  2021      4 2021-04-12
# 22       Spaghetti Squash   6.17       Paris  2021      5 2021-05-29
# 3        Eggplant Italian   3.73       Paris  2021      1 2021-01-23
# 1        Hot Choc Vending   1.08       Perth  2021      1 2021-01-19
# 44                Chevril  59.42       Perth  2021     10 2021-10-18
# 26                Grapes   58.27       Perth  2021      7 2021-07-14
# 37                Pastry   57.95       Perth  2021      9 2021-09-03
# 10               Venison    0.08       Perth  2021      2 2021-02-12
# 11                  Salt    2.03       Perth  2021      3 2021-03-18
# 23  Breakfast Quesadillas   0.85       Perth  2021      5 2021-05-09
# 31                Cheese   59.29       Perth  2021      8 2021-08-23
# 6               Tarragon    3.46       Perth  2021      2 2021-02-14
# 49                 Bread   59.95       Perth  2021     10 2021-10-03
#
#     New Trolley Inventory?  Avg Price per Product   Variance  Rank
# 34                    True              21.814839  37.655161     1
# 21                   False              26.033333  24.963333     4
# 45                    True              18.227857  36.352143     2
# 28                    True              22.541194  34.648806     5
# 4                    False              26.529565  25.379565     3
# 5                    False              26.842222  23.552222     5
# 41                    True              23.845260  34.804740     4
# 7                    False              29.840526  27.450526     2
# 32                    True              23.845260  35.464740     3
# 14                   False              32.909333  32.669333     1
# 29                    True              16.748571  38.061429     4
# 30                    True              21.537273  38.102727     3
# 17                   False              28.604286  27.954286     4
# 16                   False              30.627778  27.867778     5
# 15                   False              30.639091  29.129091     2
# 24                   False              32.030000  31.400000     1
# 40                    True              17.968000  40.292000     1
# 8                    False              29.750000  28.270000     3
# 25                    True              19.973800  38.356200     2
# 48                    True              18.872000  37.108000     5
# 38                    True              15.720000  38.460000     2
# 39                    True              21.980896  37.849104     3
# 43                    True              16.502500  42.807500     1
# 46                    True              22.000114  37.339886     5
# 27                    True              21.798448  37.341552     4
# 0                    False              42.611667  41.701667     1
# 9                    False              37.060000  32.820000     2
# 20                   False              29.234545  29.214545     4
# 18                   False              28.093333  27.043333     5
# 13                   False              30.639091  30.479091     3
# 12                   False              28.407500  28.087500     5
# 2                    False              40.902500  37.992500     1
# 36                    True              22.000114  36.939886     3
# 35                    True              22.674681  37.075319     2
# 42                    True              19.246667  39.533333     1
# 33                    True              23.517241  36.342759     4
# 47                    True              21.844444  36.325556     5
# 19                   False              34.653750  31.553750     3
# 22                   False              35.864000  29.694000     4
# 3                    False              35.298333  31.568333     2
# 1                    False              29.518000  28.438000     3
# 44                    True              21.093333  38.326667     1
# 26                    True              20.596429  37.673571     2
# 37                    True              22.000114  35.949886     4
# 10                   False              27.567273  27.487273     4
# 11                   False              28.657037  26.627037     5
# 23                   False              29.334000  28.484000     2
# 31                    True              23.361520  35.928480     5
# 6                    False              32.761818  29.301818     1
# 49                    True              23.129547  36.820453     3
