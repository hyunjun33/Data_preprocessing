# %% [markdown]
# ## 2021: Week 38 - Trilogy
#
# Recently, I've been playing with data about the best movie trilogies of all time, according to IMDb. So I thought I'd create a Preppin' Data challenge to allow you all to do the same!
#
# ![img](https://1.bp.blogspot.com/--LsfG5paGCA/YUnvc86nCYI/AAAAAAAAA9A/2yvgv7PjYvUlZoIbzNoamdhy___L18nFQCLcBGAsYHQ/w361-h400/IMDb%2BTrilogies%2B%25282%2529.png)
#
# ### Input
# There are 2 inputs for this challenge:
# 1. Top 30 Trilogies
# ![img](https://lh3.googleusercontent.com/-9oMAAJIswNM/YUnw0zlu8pI/AAAAAAAAA9I/2UhWz5WL1SIXtFdeJwALe1Y80FmldZHUwCLcBGAsYHQ/image.png)
#
# 2. Films
# ![img](https://lh3.googleusercontent.com/-Ug52cT9O70Y/YUnxDEi_nTI/AAAAAAAAA9M/F2udZ_-nVMMEW31UBlPrNq40oLq0G5lnwCLcBGAsYHQ/w400-h95/image.png)
#
# ### Requirement
# - Input the data
# - Split out the Number in Series field into Film Order and Total Films in Series
# - Work out the average rating for each trilogy
# - Work out the highest ranking for each trilogy
# - Rank the trilogies based on the average rating and use the highest ranking metric to break ties (make sure you haven't rounded the numeric fields yet!)
#     - We have noticed a slight error in the way that Tableau Prep is calculating this rank, so don't worry if your output is different to ours, we are investigating!
# - Remove the word trilogy from the Trilogy field
# - Bring the 2 datasets together by the ranking fields
# - Output the data
#
# ### Output
# ![img](https://lh3.googleusercontent.com/-1h_wQ7twRnY/YUnz-XfcXNI/AAAAAAAAA9Y/3j7LZD5aEIICn3ZWWpceTicFuAI--RZUwCLcBGAsYHQ/w640-h128/image.png)
#
# - 7 fields
#     - Trilogy Ranking
#     - Trilogy
#     - Trilogy Average
#     - Film Order
#     - Title
#     - Rating
#     - Total Films in Series
# - 90 rows (91 including headers)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Input the data

# %%
data = pd.read_excel("./data/Trilogies Input.xlsx", sheet_name=[0, 1])
top_30 = data[0].copy()
films = data[1].copy()

# %%
top_30.head()
# Out:
#    Trilogy Ranking                    Trilogy
# 0                1  Lord of the Rings trilogy
# 1                2      The Godfather trilogy
# 2                4          Star Wars trilogy
# 3                3    The Dark Knight trilogy
# 4                5            Dollars trilogy

# %%
films.head()
# Out:
#   Number in Series                  Trilogy Grouping  \
# 0              2/3  06d49632c9dc9bcb62aeaef99612ba6b
# 1              1/3  06d49632c9dc9bcb62aeaef99612ba6b
# 2              3/3  06d49632c9dc9bcb62aeaef99612ba6b
# 3              3/3  08985faab9f27113eef8adfc2200ac27
# 4              2/3  08985faab9f27113eef8adfc2200ac27
#
#                                                Title  Rating
# 0              The Lord of the Rings: The Two Towers     8.7
# 1  The Lord of the Rings: The Fellowship of the Ring     8.8
# 2      The Lord of the Rings: The Return of the King     8.9
# 3                                              Babel     7.4
# 4                                           21 Grams     7.6

# %%
top_30 = top_30.sort_values(by="Trilogy Ranking",ascending=True)
top_30.head()
# Out:
#    Trilogy Ranking                    Trilogy
# 0                1  Lord of the Rings trilogy
# 1                2      The Godfather trilogy
# 3                3    The Dark Knight trilogy
# 2                4          Star Wars trilogy
# 4                5            Dollars trilogy

# %%
### Split out the Number in Series field into Film Order and Total Films in Series

# %%
splits = films["Number in Series"].str.split("/").apply(pd.Series).rename(columns={0: "Film Order", 1: "Total Films in Series"})
films = pd.concat([films, splits], axis=1).drop("Number in Series", axis=1)
films.head()
# Out:
#                    Trilogy Grouping  \
# 0  06d49632c9dc9bcb62aeaef99612ba6b
# 1  06d49632c9dc9bcb62aeaef99612ba6b
# 2  06d49632c9dc9bcb62aeaef99612ba6b
# 3  08985faab9f27113eef8adfc2200ac27
# 4  08985faab9f27113eef8adfc2200ac27
#
#                                                Title  Rating Film Order  \
# 0              The Lord of the Rings: The Two Towers     8.7          2
# 1  The Lord of the Rings: The Fellowship of the Ring     8.8          1
# 2      The Lord of the Rings: The Return of the King     8.9          3
# 3                                              Babel     7.4          3
# 4                                           21 Grams     7.6          2
#
#   Total Films in Series
# 0                     3
# 1                     3
# 2                     3
# 3                     3
# 4                     3

# %%
### Work out the average rating for each trilogy

# %%
avg_rate = films.groupby(["Trilogy Grouping"])["Rating"].mean()
avg_rate.name = "Trilogy Average"
avg_rate
# Out:
# Trilogy Grouping
# 06d49632c9dc9bcb62aeaef99612ba6b    8.800000
# 08985faab9f27113eef8adfc2200ac27    7.700000
# 13a893bc3f0877d224af0d73de3f0359    6.833333
# 161b0061457968be63e99de104b79892    6.933333
# 209104330778fc9558cd63c51f6205d5    6.933333
# 309fc7d3bc53bb63ac42e359260ac740    8.533333
# 34f1bcfc647cfa2931f5b1e78d8011d2    8.033333
# 4a6c252c118bb7c69d8ea2a3022429e8    7.466667
# 5b78583b25bb5e0c17412e0c18177954    6.766667
# 5b9a02dc8c23ddbd9b7c6ff35ce013c6    6.833333
# 67ae81acd95388b4876c74c7725f1a3b    7.900000
# 6d5ababb65e9ff214b73e891b4afe6e8    8.600000
# 712a52bc5e7f8dc3cb5de157dbb08151    8.333333
# 71f6794efc68c56fbee873fa5fb5503a    7.166667
# 854b85cbff2752fcb88606bca76f83c6    8.166667
# 86ce15a7f39fc14323b76c9b95c66165    7.866667
# 928727f61cbc2f7507785834c5e11d48    7.000000
# 92e4d2da3d1528bc9f6668bbc26d633e    7.866667
# a734c94d6e046c4667fea57758c5b6f6    8.133333
# aabfb4cb5917aab2819ec029a588256c    7.433333
# abbf733a570a84955fc8eee18d7fc40b    6.766667
# b43e28d1b129619d9a1e8186df0d2e18    7.566667
# b4533e2140a5456efe748e17e2bc48c9    6.633333
# c5940e567348894860e9e45434682f5f    7.033333
# cd1075d848a5e0142bd3b5d66726041c    8.533333
# cea784396811723f7a4c0a1cd85f5930    7.666667
# d04fc290aedb6f25a3f9167981b396d6    7.333333
# d490830a812f1555635a1a992db882d1    7.566667
# e83db1679042124e3ccd1cbba07c86e9    7.566667
# f4adcd991ad157a5bb4b0a89e0e189a3    7.133333
# Name: Trilogy Average, dtype: float64

# %%
films = films.merge(avg_rate, how="left", left_on="Trilogy Grouping", right_on="Trilogy Grouping")
films.head()
# Out:
#                    Trilogy Grouping  \
# 0  06d49632c9dc9bcb62aeaef99612ba6b
# 1  06d49632c9dc9bcb62aeaef99612ba6b
# 2  06d49632c9dc9bcb62aeaef99612ba6b
# 3  08985faab9f27113eef8adfc2200ac27
# 4  08985faab9f27113eef8adfc2200ac27
#
#                                                Title  Rating Film Order  \
# 0              The Lord of the Rings: The Two Towers     8.7          2
# 1  The Lord of the Rings: The Fellowship of the Ring     8.8          1
# 2      The Lord of the Rings: The Return of the King     8.9          3
# 3                                              Babel     7.4          3
# 4                                           21 Grams     7.6          2
#
#   Total Films in Series  Trilogy Average
# 0                     3              8.8
# 1                     3              8.8
# 2                     3              8.8
# 3                     3              7.7
# 4                     3              7.7

# %%
### Work out the highest ranking for each trilogy
# Out:
# (30,)

# %%
title_only = films["Title"].str.split(":").apply(pd.Series)[0]
title_only = title_only.str.strip()
title_only.head()
# Out:
# 0    The Lord of the Rings
# 1    The Lord of the Rings
# 2    The Lord of the Rings
# 3                    Babel
# 4                 21 Grams
# Name: 0, dtype: object

# %%
films["Name"] = title_only
films.head()
# Out:
#                    Trilogy Grouping  \
# 0  06d49632c9dc9bcb62aeaef99612ba6b
# 1  06d49632c9dc9bcb62aeaef99612ba6b
# 2  06d49632c9dc9bcb62aeaef99612ba6b
# 3  08985faab9f27113eef8adfc2200ac27
# 4  08985faab9f27113eef8adfc2200ac27
#
#                                                Title  Rating Film Order  \
# 0              The Lord of the Rings: The Two Towers     8.7          2
# 1  The Lord of the Rings: The Fellowship of the Ring     8.8          1
# 2      The Lord of the Rings: The Return of the King     8.9          3
# 3                                              Babel     7.4          3
# 4                                           21 Grams     7.6          2
#
#   Total Films in Series  Trilogy Average                   Name
# 0                     3              8.8  The Lord of the Rings
# 1                     3              8.8  The Lord of the Rings
# 2                     3              8.8  The Lord of the Rings
# 3                     3              7.7                  Babel
# 4                     3              7.7               21 Grams

# %%
top_30["Trilogy"] = top_30["Trilogy"].str.split("trilo").apply(pd.Series)[0]
top_30["Trilogy"] = top_30["Trilogy"].str.strip()
top_30["Trilogy"]
# Out:
# 0           Lord of the Rings
# 1               The Godfather
# 3             The Dark Knight
# 2                   Star Wars
# 4                     Dollars
# 5            Once Upon a Time
# 6                   Toy Story
# 7                  The Before
# 9          Back to the Future
# 10              The Vengeance
# 8               Three Colours
# 11                      Death
# 12                 The Hobbit
# 14    Three Flavours Cornetto
# 16                     Matrix
# 13                  Evil Dead
# 15            Captain America
# 17                 Millennium
# 18                   Iron Man
# 20                      X-Men
# 19                  Wolverine
# 21                    Ocean's
# 23              The Naked Gun
# 24                 Spider-Man
# 22                    Mad Max
# 25                    Prequel
# 27                     Mexico
# 28                        MIB
# 26                 Madagascar
# 29               The Hangover
# Name: Trilogy, dtype: object

# %%
top_30
# Out:
#     Trilogy Ranking                  Trilogy
# 0                 1        Lord of the Rings
# 1                 2            The Godfather
# 3                 3          The Dark Knight
# 2                 4                Star Wars
# 4                 5                  Dollars
# 5                 6         Once Upon a Time
# 6                 7                Toy Story
# 7                 8               The Before
# 9                 9       Back to the Future
# 10               10            The Vengeance
# 8                11            Three Colours
# 11               12                    Death
# 12               13               The Hobbit
# 14               14  Three Flavours Cornetto
# 16               15                   Matrix
# 13               16                Evil Dead
# 15               17          Captain America
# 17               18               Millennium
# 18               19                 Iron Man
# 20               20                    X-Men
# 19               21                Wolverine
# 21               22                  Ocean's
# 23               23            The Naked Gun
# 24               24               Spider-Man
# 22               25                  Mad Max
# 25               26                  Prequel
# 27               27                   Mexico
# 28               28                      MIB
# 26               29               Madagascar
# 29               30             The Hangover

# %%
films.drop_duplicates(subset="Trilogy Grouping").sort_values(by="Rating", ascending=False)
# Out:
#                     Trilogy Grouping  \
# 0   06d49632c9dc9bcb62aeaef99612ba6b
# 15  309fc7d3bc53bb63ac42e359260ac740
# 72  cd1075d848a5e0142bd3b5d66726041c
# 36  712a52bc5e7f8dc3cb5de157dbb08151
# 54  a734c94d6e046c4667fea57758c5b6f6
# 18  34f1bcfc647cfa2931f5b1e78d8011d2
# 33  6d5ababb65e9ff214b73e891b4afe6e8
# 51  92e4d2da3d1528bc9f6668bbc26d633e
# 42  854b85cbff2752fcb88606bca76f83c6
# 45  86ce15a7f39fc14323b76c9b95c66165
# 81  d490830a812f1555635a1a992db882d1
# 30  67ae81acd95388b4876c74c7725f1a3b
# 3   08985faab9f27113eef8adfc2200ac27
# 75  cea784396811723f7a4c0a1cd85f5930
# 57  aabfb4cb5917aab2819ec029a588256c
# 63  b43e28d1b129619d9a1e8186df0d2e18
# 78  d04fc290aedb6f25a3f9167981b396d6
# 21  4a6c252c118bb7c69d8ea2a3022429e8
# 84  e83db1679042124e3ccd1cbba07c86e9
# 39  71f6794efc68c56fbee873fa5fb5503a
# 60  abbf733a570a84955fc8eee18d7fc40b
# 87  f4adcd991ad157a5bb4b0a89e0e189a3
# 69  c5940e567348894860e9e45434682f5f
# 6   13a893bc3f0877d224af0d73de3f0359
# 48  928727f61cbc2f7507785834c5e11d48
# 27  5b9a02dc8c23ddbd9b7c6ff35ce013c6
# 12  209104330778fc9558cd63c51f6205d5
# 9   161b0061457968be63e99de104b79892
# 24  5b78583b25bb5e0c17412e0c18177954
# 66  b4533e2140a5456efe748e17e2bc48c9
#
#                                         Title  Rating Film Order  \
# 0       The Lord of the Rings: The Two Towers     8.7          2
# 15              Star Wars: Return of the Jedi     8.3          6
# 72                              Batman Begins     8.2          1
# 36                       A Fistful of Dollars     8.0          1
# 54                                Toy Story 2     7.9          2
# 18                            Before Midnight     7.9          3
# 33                     The Godfather Part III     7.6          3
# 51                        Three Colors: White     7.6          2
# 42                      A Fistful of Dynamite     7.6          2
# 45                 Sympathy for Mr. Vengeance     7.6          1
# 81                              The Evil Dead     7.5          1
# 30                Back to the Future Part III     7.4          3
# 3                                       Babel     7.4          3
# 75  The Hobbit: The Battle of the Five Armies     7.4          3
# 57              The Girl Who Played with Fire     7.2          2
# 63                            The World's End     7.0          3
# 78                                 Iron Man 2     7.0          2
# 21         Captain America: The First Avenger     6.9          1
# 84                     The Matrix Revolutions     6.8          3
# 39                      X-Men: The Last Stand     6.7          3
# 60                Madagascar: Escape 2 Africa     6.6          2
# 87                   X-Men Origins: Wolverine     6.6          4
# 69                             Ocean's Twelve     6.5          2
# 6   Star Wars: Episode I - The Phantom Menace     6.5          1
# 48         Naked Gun 33 1/3: The Final Insult     6.5          3
# 27                 Once Upon a Time in Mexico     6.4          3
# 12                 Mad Max Beyond Thunderdome     6.3          3
# 9                                Spider-Man 3     6.2          3
# 24                            Men in Black II     6.2          2
# 66                      The Hangover Part III     5.8          3
#
#    Total Films in Series  Trilogy Average                           Name
# 0                      3         8.800000          The Lord of the Rings
# 15                     9         8.533333                      Star Wars
# 72                     3         8.533333                  Batman Begins
# 36                     3         8.333333           A Fistful of Dollars
# 54                     4         8.133333                    Toy Story 2
# 18                     3         8.033333                Before Midnight
# 33                     3         8.600000         The Godfather Part III
# 51                     3         7.866667                   Three Colors
# 42                     3         8.166667          A Fistful of Dynamite
# 45                     3         7.866667     Sympathy for Mr. Vengeance
# 81                     4         7.566667                  The Evil Dead
# 30                     3         7.900000    Back to the Future Part III
# 3                      3         7.700000                          Babel
# 75                     3         7.666667                     The Hobbit
# 57                     3         7.433333  The Girl Who Played with Fire
# 63                     3         7.566667                The World's End
# 78                     3         7.333333                     Iron Man 2
# 21                     3         7.466667                Captain America
# 84                     3         7.566667         The Matrix Revolutions
# 39                    10         7.166667                          X-Men
# 60                     3         6.766667                     Madagascar
# 87                    10         7.133333                  X-Men Origins
# 69                     4         7.033333                 Ocean's Twelve
# 6                      9         6.833333                      Star Wars
# 48                     3         7.000000               Naked Gun 33 1/3
# 27                     3         6.833333     Once Upon a Time in Mexico
# 12                     4         6.933333     Mad Max Beyond Thunderdome
# 9                      3         6.933333                   Spider-Man 3
# 24                     4         6.766667                Men in Black II
# 66                     3         6.633333          The Hangover Part III
