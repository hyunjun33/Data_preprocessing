# %% [markdown]
# ## 2021: Week 28 - It's Coming Rome
#
# '55 years of hurt, Never stopped me dreaming!'
#
# It was another night of pain for England fans on Sunday evening when they lost yet another penalty shootout in the European Football Championship final. This seems like it has been a common outcome for a lot of the tournaments that England have taken part in over the years, but what does the data agree?
#
# The challenge this week is to analyse the all of the penalty shootouts in the World Cup and European Championships (Euro's) since 1976.
#
# ### Input
# Data is from Wikipedia (World Cup & Euro's) and is two sheets
#
# ### Requirements
# - Input Data
# - Determine what competition each penalty was taken in
# - Clean any fields, correctly format the date the penalty was taken, & group the two German countries (eg, West Germany & Germany)
# - Rank the countries on the following:
#     - Shootout win % (exclude teams who have never won a shootout)
#     - Penalties scored %
# - What is the most and least successful time to take a penalty? (What penalty number are you most likely to score or miss?)
# - Output the Data
#
# ### Outputs
# 3 Outputs:
# 1. Win % Rankings (5 fields, 26 rows)
# 2. Scored % Rankings (5 fields, 34 rows)
# 3. Penalty Position Rankings (6 fields, 9 rows)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Input Data

# %%
data = pd.read_excel("./data/InternationalPenalties.xlsx", sheet_name=["WorldCup", "Euros"])

# %%
world_cup = data["WorldCup"].copy()
euros = data["Euros"].copy()

# %% [markdown]
# ### Determine what competition each penalty was taken in

# %%
world_cup.columns
# Out:
# Index(['No.', 'Penalty Number ', 'Event Year', 'Winner', 'Full Time Score',
#        'Loser', 'Winning Team GK', 'Winning team Taker', 'Losing team Taker',
#        'Losing Team GK', 'Round', 'Date'],
#       dtype='object')

# %%
world_cup["Penalty Number "].value_counts()
# Out:
# 1    30
# 2    30
# 3    30
# 4    30
# 5    24
# 6     2
# Name: Penalty Number , dtype: int64

# %%
world_cup.head()
# Out:
#    No.  Penalty Number  Event Year         Winner Full Time Score    Loser  \
# 0    1                1      1982,   West Germany             3–3   France
# 1    1                2      1982,   West Germany             3–3   France
# 2    1                3      1982,   West Germany             3–3   France
# 3    1                4      1982,   West Germany             3–3   France
# 4    1                5      1982,   West Germany             3–3   France
#
#   Winning Team GK         Winning team Taker         Losing team Taker  \
# 0      Schumacher       Kaltz Penalty scored    Penalty scored Giresse
# 1      Schumacher    Breitner Penalty scored     Penalty scored Amoros
# 2      Schumacher    Stielike Penalty missed  Penalty scored Rocheteau
# 3      Schumacher  Littbarski Penalty scored        Penalty missed Six
# 4      Schumacher  Rummenigge Penalty scored    Penalty scored Platini
#
#   Losing Team GK        Round       Date
# 0         Ettori  Semi-finals 2021-07-08
# 1         Ettori  Semi-finals 2021-07-08
# 2         Ettori  Semi-finals 2021-07-08
# 3         Ettori  Semi-finals 2021-07-08
# 4         Ettori  Semi-finals 2021-07-08

# %%
euros.columns
# Out:
# Index(['No.', 'Penalty Number', 'Event Year', 'Winner', 'Full Time Score',
#        'Loser', 'Winning team GK', 'Winning team Taker', 'Losing team Taker',
#        'Losing team GK', 'Round', 'Date'],
#       dtype='object')

# %%
euros["Penalty Number"].value_counts()
# Out:
# 1    22
# 2    22
# 3    22
# 4    22
# 5    19
# 6     6
# 7     3
# 8     2
# 9     2
# Name: Penalty Number, dtype: int64

# %%
# winner_penalty = world_cup["Winning team Taker"].str.split().apply(pd.Series)
# winner_penalty["Winner Penalty type"] = winner_penalty[2]
# winner_penalty = winner_penalty.drop([0, 1, 2, 3, 4, 5], axis=1)
# winner_penalty

# %%
def find_penalty_type(string):
    import re
    regex = re.compile("scored")
    if string == "Unknown":
        return np.nan
    match_obj = regex.search(string)
    if match_obj != None:
        return match_obj.group()
    else:
        return "missed"

# %%
world_cup["Winning team Taker"] = world_cup["Winning team Taker"].fillna("Unknown")
world_cup["Losing team Taker"] = world_cup["Losing team Taker"].fillna("Unknown")

winner_penalty = world_cup["Winning team Taker"].map(lambda x: find_penalty_type(x))
loser_penalty = world_cup["Losing team Taker"].map(lambda x: find_penalty_type(x))

# %%
winner_penalty.value_counts()
# Out:
# scored    120
# missed     21
# Name: Winning team Taker, dtype: int64

# %%
loser_penalty.value_counts()
# Out:
# scored    76
# missed    62
# Name: Losing team Taker, dtype: int64

# %%
# loser_penalty = world_cup["Losing team Taker"].str.split().apply(pd.Series)
# loser_penalty["Loser Penalty type"] = loser_penalty[1]
# loser_penalty = loser_penalty.drop([0, 1, 2, 3, 4], axis=1)
# loser_penalty

# %%
winner_penalty
# Out:
# 0      scored
# 1      scored
# 2      missed
# 3      scored
# 4      scored
#         ...
# 141    scored
# 142    missed
# 143    scored
# 144    scored
# 145    scored
# Name: Winning team Taker, Length: 146, dtype: object

# %%
world_cup["Winner Penalty type"] = winner_penalty
world_cup["Loser Penalty type"] = loser_penalty

# %%
euros
# Out:
#      No.  Penalty Number Event Year           Winner Full Time Score  \
# 0      1               1      1976,   Czechoslovakia             2–2
# 1      1               2      1976,   Czechoslovakia             2–2
# 2      1               3      1976,   Czechoslovakia             2–2
# 3      1               4      1976,   Czechoslovakia             2–2
# 4      1               5      1976,   Czechoslovakia             2–2
# ..   ...             ...        ...              ...             ...
# 115   22               1      2020,            Italy             1–1
# 116   22               2      2020,            Italy             1–1
# 117   22               3      2020,            Italy             1–1
# 118   22               4      2020,            Italy             1–1
# 119   22               5      2020,            Italy             1–1
#
#              Loser Winning team GK           Winning team Taker  \
# 0     West Germany          Viktor         Masný Penalty scored
# 1     West Germany          Viktor        Nehoda Penalty scored
# 2     West Germany          Viktor        Ondruš Penalty scored
# 3     West Germany          Viktor      Jurkemik Penalty scored
# 4     West Germany          Viktor       Panenka Penalty scored
# ..             ...             ...                          ...
# 115        England      Donnarumma       Berardi Penalty scored
# 116        England      Donnarumma       Belotti Penalty missed
# 117        England      Donnarumma       Bonucci Penalty scored
# 118        England      Donnarumma  Bernardeschi Penalty scored
# 119        England      Donnarumma      Jorginho Penalty missed
#
#            Losing team Taker Losing team GK  Round       Date
# 0      Penalty scored Bonhof          Maier  Final 2021-06-20
# 1       Penalty scored Flohe          Maier  Final 2021-06-20
# 2    Penalty scored Bongartz          Maier  Final 2021-06-20
# 3      Penalty missed Hoeneß          Maier  Final 2021-06-20
# 4                        NaN          Maier  Final 2021-06-20
# ..                       ...            ...    ...        ...
# 115      Penalty scored Kane       Pickford  Final 2021-07-11
# 116   Penalty scored Maguire       Pickford  Final 2021-07-11
# 117  Penalty missed Rashford       Pickford  Final 2021-07-11
# 118    Penalty missed Sancho       Pickford  Final 2021-07-11
# 119      Penalty missed Saka       Pickford  Final 2021-07-11
#
# [120 rows x 12 columns]

# %%
euros["Winning team Taker"] = euros["Winning team Taker"].fillna("Unknown")
euros["Losing team Taker"] = euros["Losing team Taker"].fillna("Unknown")

euros_winner_penalty = euros["Winning team Taker"].map(lambda x: find_penalty_type(x))
euros_loser_penalty = euros["Losing team Taker"].map(lambda x: find_penalty_type(x))

# %%
euros_winner_penalty.value_counts()
# Out:
# scored    105
# missed     14
# Name: Winning team Taker, dtype: int64

# %%
euros_loser_penalty.value_counts()
# Out:
# scored    73
# missed    40
# Name: Losing team Taker, dtype: int64

# %%
euros["Winner Penalty type"] = euros_winner_penalty
euros["Loser Penalty type"] = euros_loser_penalty
euros
# Out:
#      No.  Penalty Number Event Year           Winner Full Time Score  \
# 0      1               1      1976,   Czechoslovakia             2–2
# 1      1               2      1976,   Czechoslovakia             2–2
# 2      1               3      1976,   Czechoslovakia             2–2
# 3      1               4      1976,   Czechoslovakia             2–2
# 4      1               5      1976,   Czechoslovakia             2–2
# ..   ...             ...        ...              ...             ...
# 115   22               1      2020,            Italy             1–1
# 116   22               2      2020,            Italy             1–1
# 117   22               3      2020,            Italy             1–1
# 118   22               4      2020,            Italy             1–1
# 119   22               5      2020,            Italy             1–1
#
#              Loser Winning team GK           Winning team Taker  \
# 0     West Germany          Viktor         Masný Penalty scored
# 1     West Germany          Viktor        Nehoda Penalty scored
# 2     West Germany          Viktor        Ondruš Penalty scored
# 3     West Germany          Viktor      Jurkemik Penalty scored
# 4     West Germany          Viktor       Panenka Penalty scored
# ..             ...             ...                          ...
# 115        England      Donnarumma       Berardi Penalty scored
# 116        England      Donnarumma       Belotti Penalty missed
# 117        England      Donnarumma       Bonucci Penalty scored
# 118        England      Donnarumma  Bernardeschi Penalty scored
# 119        England      Donnarumma      Jorginho Penalty missed
#
#            Losing team Taker Losing team GK  Round       Date  \
# 0      Penalty scored Bonhof          Maier  Final 2021-06-20
# 1       Penalty scored Flohe          Maier  Final 2021-06-20
# 2    Penalty scored Bongartz          Maier  Final 2021-06-20
# 3      Penalty missed Hoeneß          Maier  Final 2021-06-20
# 4                    Unknown          Maier  Final 2021-06-20
# ..                       ...            ...    ...        ...
# 115      Penalty scored Kane       Pickford  Final 2021-07-11
# 116   Penalty scored Maguire       Pickford  Final 2021-07-11
# 117  Penalty missed Rashford       Pickford  Final 2021-07-11
# 118    Penalty missed Sancho       Pickford  Final 2021-07-11
# 119      Penalty missed Saka       Pickford  Final 2021-07-11
#
#     Winner Penalty type Loser Penalty type
# 0                scored             scored
# 1                scored             scored
# 2                scored             scored
# 3                scored             missed
# 4                scored                NaN
# ..                  ...                ...
# 115              scored             scored
# 116              missed             scored
# 117              scored             missed
# 118              scored             missed
# 119              missed             missed
#
# [120 rows x 14 columns]

# %% [markdown]
# ### Clean any fields, correctly format the date the penalty was taken, & group the two German countries (eg, West Germany & Germany)

# %%
world_cup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   No.                  146 non-null    int64
#  1   Penalty Number       146 non-null    int64
#  2   Event Year           146 non-null    object
#  3   Winner               146 non-null    object
#  4   Full Time Score      146 non-null    object
#  5   Loser                146 non-null    object
#  6   Winning Team GK      146 non-null    object
#  7   Winning team Taker   146 non-null    object
#  8   Losing team Taker    146 non-null    object
#  9   Losing Team GK       146 non-null    object
#  10  Round                146 non-null    object
#  11  Date                 146 non-null    datetime64[ns]
#  12  Winner Penalty type  141 non-null    object
#  13  Loser Penalty type   138 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(11)
# memory usage: 16.1+ KB

# %%
world_cup["Event Year"] = pd.to_datetime(world_cup["Event Year"].str.replace(",", ""))
world_cup["Event Year"] = world_cup["Event Year"].map(lambda x: x.year)

# %%
world_cup["Winner"] = world_cup["Winner"].str.strip()
world_cup["Loser"] = world_cup["Loser"].str.strip()

# %%
world_cup.loc[world_cup["Winner"] == "West Germany", "Winner"] = "Germany"

# %%
world_cup[world_cup["Winner"] == "Germany"].shape
# Out:
# (19, 14)

# %%
euros["Winner"].value_counts()
# Out:
#  Spain             20
#  Italy             19
#  Germany           15
#  Czechoslovakia    14
#  Portugal          12
#  Czech Republic     6
#  Netherlands        6
#  Denmark            5
#  France             5
#  Poland             5
#   Switzerland       5
#  England            4
#  Turkey             4
# Name: Winner, dtype: int64

# %%
euros["Winner"] = euros["Winner"].str.strip()
euros["Winner"].value_counts()
# Out:
# Spain             20
# Italy             19
# Germany           15
# Czechoslovakia    14
# Portugal          12
# Czech Republic     6
# Netherlands        6
# Denmark            5
# France             5
# Poland             5
# Switzerland        5
# England            4
# Turkey             4
# Name: Winner, dtype: int64

# %%
euros["Loser"] = euros["Loser"].str.strip()
euros["Loser"].value_counts()
# Out:
# Italy           23
# England         23
# Netherlands     14
# France          11
# Switzerland     10
# Spain            9
# Sweden           6
# West Germany     5
# Denmark          5
# Portugal         5
# Poland           5
# Croatia          4
# Name: Loser, dtype: int64

# %%
euros.loc[euros["Loser"] == "West Germany", "Loser"] = "Germany"

# %%
euros.shape
# Out:
# (120, 14)

# %%
euros.head()
# Out:
#    No.  Penalty Number Event Year          Winner Full Time Score    Loser  \
# 0    1               1      1976,  Czechoslovakia             2–2  Germany
# 1    1               2      1976,  Czechoslovakia             2–2  Germany
# 2    1               3      1976,  Czechoslovakia             2–2  Germany
# 3    1               4      1976,  Czechoslovakia             2–2  Germany
# 4    1               5      1976,  Czechoslovakia             2–2  Germany
#
#   Winning team GK       Winning team Taker        Losing team Taker  \
# 0          Viktor     Masný Penalty scored    Penalty scored Bonhof
# 1          Viktor    Nehoda Penalty scored     Penalty scored Flohe
# 2          Viktor    Ondruš Penalty scored  Penalty scored Bongartz
# 3          Viktor  Jurkemik Penalty scored    Penalty missed Hoeneß
# 4          Viktor   Panenka Penalty scored                  Unknown
#
#   Losing team GK  Round       Date Winner Penalty type Loser Penalty type
# 0          Maier  Final 2021-06-20              scored             scored
# 1          Maier  Final 2021-06-20              scored             scored
# 2          Maier  Final 2021-06-20              scored             scored
# 3          Maier  Final 2021-06-20              scored             missed
# 4          Maier  Final 2021-06-20              scored                NaN

# %% [markdown]
# ### Null value replacement

# %%
world_cup.loc[world_cup["Winner"] == "South Korea", "Winner Penalty type"] = "scored"

# %%
world_cup.loc[19, "Winner Penalty type"] = "scored"

# %%
world_cup.loc[[45, 48, 94, 95, 107, 117], "Winner Penalty type"] = "scored"
world_cup.loc[105, "Winner Penalty type"] = "missed"

# %%
world_cup[world_cup["Winner Penalty type"].isna()]
# Out:
#      No.  Penalty Number   Event Year       Winner Full Time Score  \
# 34     7                5        1990    Argentina             1–1
# 39     8                5        1990      Germany             1–1
# 54    11                5        1994       Brazil             0–0
# 121   25                5        2014  Netherlands             0–0
# 130   27                5        2018       Russia             1–1
#
#           Loser Winning Team GK Winning team Taker         Losing team Taker  \
# 34        Italy       Goycochea            Unknown     Penalty missed Serena
# 39      England         Illgner            Unknown     Penalty missed Waddle
# 54        Italy        Taffarel            Unknown  Penalty missed R. Baggio
# 121  Costa Rica            Krul            Unknown      Penalty missed Umaña
# 130       Spain        Akinfeev            Unknown      Penalty missed Aspas
#
#     Losing Team GK           Round       Date Winner Penalty type  \
# 34           Zenga     Semi-finals 2021-07-03                 NaN
# 39         Shilton     Semi-finals 2021-07-04                 NaN
# 54        Pagliuca           Final 2021-07-17                 NaN
# 121          Navas  Quarter-finals 2021-07-05                 NaN
# 130         De Gea    Second round 2021-07-01                 NaN
#
#     Loser Penalty type
# 34              missed
# 39              missed
# 54              missed
# 121             missed
# 130             missed

# %%
euros[euros["Winner Penalty type"].isna()]
# Out:
#     No.  Penalty Number Event Year  Winner Full Time Score    Loser  \
# 65   12               4      2008,  Turkey             1–1  Croatia
#
#    Winning team GK Winning team Taker      Losing team Taker Losing team GK  \
# 65          Reçber            Unknown  Penalty missed Petrić      Pletikosa
#
#              Round       Date Winner Penalty type Loser Penalty type
# 65  Quarter-finals 2021-06-20                 NaN             missed

# %%
euros[euros["Loser Penalty type"].isna()]
# Out:
#      No.  Penalty Number Event Year          Winner Full Time Score  \
# 4      1               5      1976,  Czechoslovakia             2–2
# 70    13               5      2008,           Spain             0–0
# 75    14               5      2012,           Italy             0–0
# 80    15               5      2012,           Spain             0–0
# 90    17               5      2016,        Portugal             1–1
# 109   20               5      2020,           Spain             1–1
# 114   21               5      2020,           Italy             1–1
#
#            Loser Winning team GK        Winning team Taker Losing team Taker  \
# 4        Germany          Viktor    Panenka Penalty scored           Unknown
# 70         Italy        Casillas   Fàbregas Penalty scored           Unknown
# 75       England          Buffon   Diamanti Penalty scored           Unknown
# 80      Portugal        Casillas   Fàbregas Penalty scored           Unknown
# 90        Poland        Patrício   Quaresma Penalty scored           Unknown
# 109  Switzerland           Simón  Oyarzabal Penalty scored           Unknown
# 114        Spain      Donnarumma   Jorginho Penalty scored           Unknown
#
#     Losing team GK           Round       Date Winner Penalty type  \
# 4            Maier           Final 2021-06-20              scored
# 70          Buffon  Quarter-finals 2021-06-22              scored
# 75            Hart  Quarter-finals 2021-06-24              scored
# 80        Patrício     Semi-finals 2021-06-27              scored
# 90       Fabiański  Quarter-finals 2021-06-30              scored
# 109         Sommer  Quarter-finals 2021-07-02              scored
# 114          Simón     Semi-finals 2021-07-06              scored
#
#     Loser Penalty type
# 4                  NaN
# 70                 NaN
# 75                 NaN
# 80                 NaN
# 90                 NaN
# 109                NaN
# 114                NaN

# %% [markdown]
# ### Rank the countries on the following:
# - Shootout win % (exclude teams who have never won a shootout)
# - Penalties scored %

# %% [markdown]
# ### Shootout win %

# %%
world_cup_shootout = world_cup.drop(["Winner Penalty type", "Loser Penalty type"], axis=1)
euros_shootout = euros.drop(["Winner Penalty type", "Loser Penalty type"], axis=1)
world_cup_shootout.shape, euros_shootout.shape
# Out:
# ((146, 12), (120, 12))

# %%
world_cup_shootout.columns = ['No.', 'Penalty Number', 'Event Year', 'Winner', 'Full Time Score',
       'Loser', 'Winning Team GK', 'Winning team Taker', 'Losing team Taker',
       'Losing Team GK', 'Round', 'Date']
euros_shootout.columns = ['No.', 'Penalty Number', 'Event Year', 'Winner', 'Full Time Score',
       'Loser', 'Winning Team GK', 'Winning team Taker', 'Losing team Taker',
       'Losing Team GK', 'Round', 'Date']

# %%
world_cup_shootout
# Out:
#      No.  Penalty Number  Event Year   Winner Full Time Score   Loser  \
# 0      1               1        1982  Germany             3–3  France
# 1      1               2        1982  Germany             3–3  France
# 2      1               3        1982  Germany             3–3  France
# 3      1               4        1982  Germany             3–3  France
# 4      1               5        1982  Germany             3–3  France
# ..   ...             ...         ...      ...             ...     ...
# 141   30               1        2018  Croatia             2–2  Russia
# 142   30               2        2018  Croatia             2–2  Russia
# 143   30               3        2018  Croatia             2–2  Russia
# 144   30               4        2018  Croatia             2–2  Russia
# 145   30               5        2018  Croatia             2–2  Russia
#
#     Winning Team GK         Winning team Taker           Losing team Taker  \
# 0        Schumacher       Kaltz Penalty scored      Penalty scored Giresse
# 1        Schumacher    Breitner Penalty scored       Penalty scored Amoros
# 2        Schumacher    Stielike Penalty missed    Penalty scored Rocheteau
# 3        Schumacher  Littbarski Penalty scored          Penalty missed Six
# 4        Schumacher  Rummenigge Penalty scored      Penalty scored Platini
# ..              ...                        ...                         ...
# 141         Subašić    Brozović Penalty scored       Penalty missed Smolov
# 142         Subašić     Kovačić Penalty missed      Penalty scored Dzagoev
# 143         Subašić      Modrić Penalty scored    Penalty missed Fernandes
# 144         Subašić        Vida Penalty scored  Penalty scored Ignashevich
# 145         Subašić     Rakitić Penalty scored     Penalty scored Kuzyayev
#
#     Losing Team GK           Round       Date
# 0           Ettori     Semi-finals 2021-07-08
# 1           Ettori     Semi-finals 2021-07-08
# 2           Ettori     Semi-finals 2021-07-08
# 3           Ettori     Semi-finals 2021-07-08
# 4           Ettori     Semi-finals 2021-07-08
# ..             ...             ...        ...
# 141       Akinfeev  Quarter-finals 2021-07-07
# 142       Akinfeev  Quarter-finals 2021-07-07
# 143       Akinfeev  Quarter-finals 2021-07-07
# 144       Akinfeev  Quarter-finals 2021-07-07
# 145       Akinfeev  Quarter-finals 2021-07-07
#
# [146 rows x 12 columns]

# %%
world_cup_shootout = world_cup_shootout.drop(["Full Time Score", "Winning Team GK", "Winning team Taker",
                "Losing team Taker", "Losing Team GK", "Round", "Date"], axis=1)
world_cup_shootout
# Out:
#      No.  Penalty Number  Event Year   Winner   Loser
# 0      1               1        1982  Germany  France
# 1      1               2        1982  Germany  France
# 2      1               3        1982  Germany  France
# 3      1               4        1982  Germany  France
# 4      1               5        1982  Germany  France
# ..   ...             ...         ...      ...     ...
# 141   30               1        2018  Croatia  Russia
# 142   30               2        2018  Croatia  Russia
# 143   30               3        2018  Croatia  Russia
# 144   30               4        2018  Croatia  Russia
# 145   30               5        2018  Croatia  Russia
#
# [146 rows x 5 columns]

# %%
euros_shootout = euros_shootout.drop(["Full Time Score", "Winning Team GK", "Winning team Taker",
                "Losing team Taker", "Losing Team GK", "Round", "Date"], axis=1)
euros_shootout
# Out:
#      No.  Penalty Number Event Year          Winner    Loser
# 0      1               1      1976,  Czechoslovakia  Germany
# 1      1               2      1976,  Czechoslovakia  Germany
# 2      1               3      1976,  Czechoslovakia  Germany
# 3      1               4      1976,  Czechoslovakia  Germany
# 4      1               5      1976,  Czechoslovakia  Germany
# ..   ...             ...        ...             ...      ...
# 115   22               1      2020,           Italy  England
# 116   22               2      2020,           Italy  England
# 117   22               3      2020,           Italy  England
# 118   22               4      2020,           Italy  England
# 119   22               5      2020,           Italy  England
#
# [120 rows x 5 columns]

# %%
world_cup_shootout = world_cup_shootout.drop_duplicates(subset=["Winner", "Loser", "Event Year"])
euros_shootout = euros_shootout.drop_duplicates(subset=["Winner", "Loser", "Event Year"])

# %%
world_cup_winner = world_cup_shootout["Winner"].value_counts()
world_cup_loser = world_cup_shootout["Loser"].value_counts()

# %%
euros_winner = euros_shootout["Winner"].value_counts()
euros_loser = euros_shootout["Loser"].value_counts()

# %%
world_cup_win_pct = pd.concat([world_cup_winner, world_cup_loser], axis=1).fillna(0)
world_cup_win_pct.columns = ["Shootouts", "lose_shootouts"]
world_cup_win_pct["Total Shootouts"] = world_cup_win_pct["Shootouts"] + world_cup_win_pct["lose_shootouts"]

# %%
euros_win_pct = pd.concat([euros_winner, euros_loser], axis=1).fillna(0)
euros_win_pct.columns = ["Shootouts", "lose_shootouts"]
euros_win_pct["Total Shootouts"] = euros_win_pct["Shootouts"] + euros_win_pct["lose_shootouts"]
euros_win_pct
# Out:
#                 Shootouts  lose_shootouts  Total Shootouts
# Spain                 4.0             2.0              6.0
# Italy                 4.0             3.0              7.0
# Czechoslovakia        2.0             0.0              2.0
# Germany               2.0             1.0              3.0
# Portugal              2.0             1.0              3.0
# Denmark               1.0             1.0              2.0
# England               1.0             4.0              5.0
# France                1.0             2.0              3.0
# Czech Republic        1.0             0.0              1.0
# Netherlands           1.0             3.0              4.0
# Turkey                1.0             0.0              1.0
# Poland                1.0             1.0              2.0
# Switzerland           1.0             2.0              3.0
# Sweden                0.0             1.0              1.0
# Croatia               0.0             1.0              1.0

# %%
total = pd.concat([world_cup_win_pct, euros_win_pct], axis=1).fillna(0)
total.columns = ["world_shootouts", "world_lose_shootouts", "world_total_shootouts",
                 "euros_shootouts", "euros_lose_shootouts", "euros_total_shootouts"]

# %%
total = total.drop(["world_lose_shootouts", "euros_lose_shootouts"], axis=1)

# %%
total.columns
# Out:
# Index(['world_shootouts', 'world_total_shootouts', 'euros_shootouts',
#        'euros_total_shootouts'],
#       dtype='object')

# %%
total["Total Shootouts"] = total["world_total_shootouts"] + total["euros_total_shootouts"]
total["Shootouts"] = total["world_shootouts"] + total["euros_shootouts"]
total = total.reset_index().rename(columns={"index": "Team"})
total = total.drop(["world_shootouts", "world_total_shootouts",
                    "euros_shootouts", "euros_total_shootouts"], axis=1)
total
# Out:
#                    Team  Total Shootouts  Shootouts
# 0               Germany              7.0        6.0
# 1             Argentina              5.0        4.0
# 2                Brazil              4.0        3.0
# 3               Croatia              3.0        2.0
# 4                France              7.0        3.0
# 5                 Italy             11.0        5.0
# 6                Russia              2.0        1.0
# 7           Netherlands              7.0        2.0
# 8            Costa Rica              2.0        1.0
# 9               Uruguay              1.0        1.0
# 10             Paraguay              1.0        1.0
# 11              Ukraine              1.0        1.0
# 12             Portugal              4.0        3.0
# 13          South Korea              1.0        1.0
# 14                Spain             10.0        5.0
# 15               Sweden              2.0        1.0
# 16             Bulgaria              1.0        1.0
# 17  Republic of Ireland              2.0        1.0
# 18              Belgium              1.0        1.0
# 19              England              9.0        2.0
# 20               Mexico              2.0        0.0
# 21              Romania              2.0        0.0
# 22                Ghana              1.0        0.0
# 23             Colombia              1.0        0.0
# 24              Denmark              3.0        1.0
# 25               Greece              1.0        0.0
# 26                Chile              1.0        0.0
# 27          Switzerland              4.0        1.0
# 28                Japan              1.0        0.0
# 29           Yugoslavia              1.0        0.0
# 30       Czechoslovakia              2.0        2.0
# 31       Czech Republic              1.0        1.0
# 32               Turkey              1.0        1.0
# 33               Poland              2.0        1.0

# %%
total["Shootout Win %"] = (total["Shootouts"] / total["Total Shootouts"] * 100).round(0)

# %%
total = total.sort_values(by="Shootout Win %", ascending=False)
no_shootout_idx = total[total["Shootout Win %"] == 0].index
total = total.drop(no_shootout_idx, axis=0).rename(columns={"index": "Team"})
total
# Out:
#                    Team  Total Shootouts  Shootouts  Shootout Win %
# 32               Turkey              1.0        1.0           100.0
# 31       Czech Republic              1.0        1.0           100.0
# 30       Czechoslovakia              2.0        2.0           100.0
# 18              Belgium              1.0        1.0           100.0
# 9               Uruguay              1.0        1.0           100.0
# 10             Paraguay              1.0        1.0           100.0
# 11              Ukraine              1.0        1.0           100.0
# 13          South Korea              1.0        1.0           100.0
# 16             Bulgaria              1.0        1.0           100.0
# 0               Germany              7.0        6.0            86.0
# 1             Argentina              5.0        4.0            80.0
# 2                Brazil              4.0        3.0            75.0
# 12             Portugal              4.0        3.0            75.0
# 3               Croatia              3.0        2.0            67.0
# 15               Sweden              2.0        1.0            50.0
# 17  Republic of Ireland              2.0        1.0            50.0
# 14                Spain             10.0        5.0            50.0
# 8            Costa Rica              2.0        1.0            50.0
# 6                Russia              2.0        1.0            50.0
# 33               Poland              2.0        1.0            50.0
# 5                 Italy             11.0        5.0            45.0
# 4                France              7.0        3.0            43.0
# 24              Denmark              3.0        1.0            33.0
# 7           Netherlands              7.0        2.0            29.0
# 27          Switzerland              4.0        1.0            25.0
# 19              England              9.0        2.0            22.0

# %%
total["Win % Rank"] = total["Shootout Win %"].rank(method="dense", ascending=False).astype(int)
total = total.reset_index(drop=True)
total = total.loc[:, ["Win % Rank", "Shootout Win %", "Total Shootouts", "Shootouts", "Team"]]

total["Shootout Win %"] = total["Shootout Win %"].astype(int)
total["Total Shootouts"] = total["Total Shootouts"].astype(int)
total["Shootouts"] = total["Shootouts"].astype(int)

total
# Out:
#     Win % Rank  Shootout Win %  Total Shootouts  Shootouts  \
# 0            1             100                1          1
# 1            1             100                1          1
# 2            1             100                2          2
# 3            1             100                1          1
# 4            1             100                1          1
# 5            1             100                1          1
# 6            1             100                1          1
# 7            1             100                1          1
# 8            1             100                1          1
# 9            2              86                7          6
# 10           3              80                5          4
# 11           4              75                4          3
# 12           4              75                4          3
# 13           5              67                3          2
# 14           6              50                2          1
# 15           6              50                2          1
# 16           6              50               10          5
# 17           6              50                2          1
# 18           6              50                2          1
# 19           6              50                2          1
# 20           7              45               11          5
# 21           8              43                7          3
# 22           9              33                3          1
# 23          10              29                7          2
# 24          11              25                4          1
# 25          12              22                9          2
#
#                    Team
# 0                Turkey
# 1        Czech Republic
# 2        Czechoslovakia
# 3               Belgium
# 4               Uruguay
# 5              Paraguay
# 6               Ukraine
# 7           South Korea
# 8              Bulgaria
# 9               Germany
# 10            Argentina
# 11               Brazil
# 12             Portugal
# 13              Croatia
# 14               Sweden
# 15  Republic of Ireland
# 16                Spain
# 17           Costa Rica
# 18               Russia
# 19               Poland
# 20                Italy
# 21               France
# 22              Denmark
# 23          Netherlands
# 24          Switzerland
# 25              England

# %% [markdown]
# ### Penalties scored %

# %%
# Penalties scored %
# world_cup["Winner Penalty type"] = world_cup["Winner Penalty type"].map({"scored": 1, "missed": 0})
# world_cup["Loser Penalty type"] = world_cup["Loser Penalty type"].map({"scored": 1, "missed": 0})

# %%
winner = (world_cup[["Winner", "Winner Penalty type"]]
              .melt(id_vars="Winner", value_name="Penalties")
              .drop("variable", axis=1)
              .rename(columns={"Winner": "Team"})

)
winner["Penalties"] = winner["Penalties"].str.strip()
winner["Penalties"] = winner["Penalties"].map({"scored": 1, "missed": 0})
winner
# Out:
#         Team  Penalties
# 0    Germany        1.0
# 1    Germany        1.0
# 2    Germany        0.0
# 3    Germany        1.0
# 4    Germany        1.0
# ..       ...        ...
# 141  Croatia        1.0
# 142  Croatia        0.0
# 143  Croatia        1.0
# 144  Croatia        1.0
# 145  Croatia        1.0
#
# [146 rows x 2 columns]

# %%
loser = (world_cup[["Loser", "Loser Penalty type"]]
             .melt(id_vars="Loser", value_name="Penalties")
             .drop("variable", axis=1)
             .rename(columns={"Loser": "Team"})
        )
loser["Penalties"] = loser["Penalties"].str.strip()
loser["Penalties"] = loser["Penalties"].map({"scored": 1, "missed": 0})
loser
# Out:
#        Team  Penalties
# 0    France        1.0
# 1    France        1.0
# 2    France        1.0
# 3    France        0.0
# 4    France        1.0
# ..      ...        ...
# 141  Russia        0.0
# 142  Russia        1.0
# 143  Russia        0.0
# 144  Russia        1.0
# 145  Russia        1.0
#
# [146 rows x 2 columns]

# %%
world_cup_penalties = pd.concat([winner, loser], axis=0)

# %%
winner = (euros[["Winner", "Winner Penalty type"]]
              .melt(id_vars="Winner", value_name="Penalties")
              .drop("variable", axis=1)
              .rename(columns={"Winner": "Team"})
         )
winner["Penalties"] = winner["Penalties"].str.strip()
winner["Penalties"] = winner["Penalties"].map({"scored": 1, "missed": 0})
winner
# Out:
#                Team  Penalties
# 0    Czechoslovakia        1.0
# 1    Czechoslovakia        1.0
# 2    Czechoslovakia        1.0
# 3    Czechoslovakia        1.0
# 4    Czechoslovakia        1.0
# ..              ...        ...
# 115           Italy        1.0
# 116           Italy        0.0
# 117           Italy        1.0
# 118           Italy        1.0
# 119           Italy        0.0
#
# [120 rows x 2 columns]

# %%
loser = (euros[["Loser", "Loser Penalty type"]]
              .melt(id_vars="Loser", value_name="Penalties")
              .drop("variable", axis=1)
              .rename(columns={"Loser": "Team"})
         )
loser["Penalties"] = loser["Penalties"].str.strip()
loser["Penalties"] = loser["Penalties"].map({"scored": 1, "missed": 0})
loser
# Out:
#         Team  Penalties
# 0    Germany        1.0
# 1    Germany        1.0
# 2    Germany        1.0
# 3    Germany        0.0
# 4    Germany        NaN
# ..       ...        ...
# 115  England        1.0
# 116  England        1.0
# 117  England        0.0
# 118  England        0.0
# 119  England        0.0
#
# [120 rows x 2 columns]

# %%
euros_penalties = pd.concat([winner, loser], axis=0)

# %%
total_penalties = pd.concat([world_cup_penalties, euros_penalties], axis=0)
total_penalties = total_penalties.dropna()

# %%
penalties_scored = total_penalties.groupby(["Team"])["Penalties"].sum()
penalties_missed = total_penalties.groupby(["Team"])["Penalties"].count() - total_penalties.groupby(["Team"])["Penalties"].sum()
penalties_total = total_penalties.groupby(["Team"])["Penalties"].count()

# %%
score_pct = pd.concat([penalties_missed, penalties_scored, penalties_total], axis=1)
score_pct.columns = ["Penalties Missed", "Penalties Scored", "Penalties Total"]
score_pct
# Out:
#                      Penalties Missed  Penalties Scored  Penalties Total
# Team
# Argentina                         5.0              17.0               22
# Belgium                           0.0               5.0                5
# Brazil                            5.0              13.0               18
# Bulgaria                          1.0               3.0                4
# Chile                             3.0               2.0                5
# Colombia                          2.0               3.0                5
# Costa Rica                        2.0               8.0               10
# Croatia                           6.0               8.0               14
# Czech Republic                    0.0               6.0                6
# Czechoslovakia                    0.0              14.0               14
# Denmark                           4.0              11.0               15
# England                          16.0              29.0               45
# France                            7.0              29.0               36
# Germany                           5.0              32.0               37
# Ghana                             2.0               2.0                4
# Greece                            1.0               3.0                4
# Italy                            19.0              42.0               61
# Japan                             1.0               3.0                4
# Mexico                            5.0               2.0                7
# Netherlands                      10.0              22.0               32
# Paraguay                          0.0               5.0                5
# Poland                            1.0               8.0                9
# Portugal                          5.0              16.0               21
# Republic of Ireland               3.0               7.0               10
# Romania                           3.0               8.0               11
# Russia                            2.0               7.0                9
# South Korea                       0.0               5.0                5
# Spain                            14.0              33.0               47
# Sweden                            3.0               9.0               12
# Switzerland                       7.0              10.0               17
# Turkey                            0.0               3.0                3
# Ukraine                           1.0               3.0                4
# Uruguay                           1.0               4.0                5
# Yugoslavia                        3.0               2.0                5

# %%
score_pct["% Total Penalties Scored"] = (score_pct["Penalties Scored"] / score_pct["Penalties Total"] * 100).round(0).astype(int)
score_pct["Penalties Scored %Rank"] = score_pct["% Total Penalties Scored"].rank(method="dense", ascending=False).astype(int)
score_pct = score_pct.sort_values(by="% Total Penalties Scored", ascending=False)
score_pct = score_pct.reset_index()
score_pct = score_pct.loc[:, ["Penalties Scored %Rank", "% Total Penalties Scored", "Penalties Missed", "Penalties Scored", "Team"]]
score_pct[["Penalties Missed", "Penalties Scored"]] = score_pct[["Penalties Missed", "Penalties Scored"]].astype(int)
score_pct
# Out:
#     Penalties Scored %Rank  % Total Penalties Scored  Penalties Missed  \
# 0                        1                       100                 0
# 1                        1                       100                 0
# 2                        1                       100                 0
# 3                        1                       100                 0
# 4                        1                       100                 0
# 5                        1                       100                 0
# 6                        2                        89                 1
# 7                        3                        86                 5
# 8                        4                        81                 7
# 9                        5                        80                 1
# 10                       5                        80                 2
# 11                       6                        78                 2
# 12                       7                        77                 5
# 13                       8                        76                 5
# 14                       9                        75                 1
# 15                       9                        75                 3
# 16                       9                        75                 1
# 17                       9                        75                 1
# 18                       9                        75                 1
# 19                      10                        73                 4
# 20                      10                        73                 3
# 21                      11                        72                 5
# 22                      12                        70                14
# 23                      12                        70                 3
# 24                      13                        69                19
# 25                      13                        69                10
# 26                      14                        64                16
# 27                      15                        60                 2
# 28                      16                        59                 7
# 29                      17                        57                 6
# 30                      18                        50                 2
# 31                      19                        40                 3
# 32                      19                        40                 3
# 33                      20                        29                 5
#
#     Penalties Scored                 Team
# 0                  5              Belgium
# 1                  3               Turkey
# 2                  5          South Korea
# 3                  6       Czech Republic
# 4                 14       Czechoslovakia
# 5                  5             Paraguay
# 6                  8               Poland
# 7                 32              Germany
# 8                 29               France
# 9                  4              Uruguay
# 10                 8           Costa Rica
# 11                 7               Russia
# 12                17            Argentina
# 13                16             Portugal
# 14                 3              Ukraine
# 15                 9               Sweden
# 16                 3                Japan
# 17                 3               Greece
# 18                 3             Bulgaria
# 19                11              Denmark
# 20                 8              Romania
# 21                13               Brazil
# 22                33                Spain
# 23                 7  Republic of Ireland
# 24                42                Italy
# 25                22          Netherlands
# 26                29              England
# 27                 3             Colombia
# 28                10          Switzerland
# 29                 8              Croatia
# 30                 2                Ghana
# 31                 2                Chile
# 32                 2           Yugoslavia
# 33                 2               Mexico
